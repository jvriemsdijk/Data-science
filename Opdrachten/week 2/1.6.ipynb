# %%
import urllib2
from bs4 import BeautifulSoup

articles = ()
for url in csv:
    html = urllib2.urlopen(url).read()
    soup = BeautifulSoup(html)
    texts = soup.findAll(text=True)
    text = soup.get_text()
    


print(soup.get_text())
# Out:
# De man die de wereld aan de Nutella bracht | Economie | de Volkskrant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# var _sf_startpt = (new Date()).getTime()
#
#
#     /**
#      Main module, holding everything to make De volkskrant work
#
#      @module App
#      **/
#     var App = {};
#
#     /* GENERAL */
#     var pe_adsLevels = [["economie", "20007", "default"]];
#     var pe_navType = 'default';
#     var xfp_posities = [
#
#
#
#             "mid--large--1", "top--large--1", "top--medium--1", "mid--small--1", "top--small--1", "rectangle--large--1", "ligatus--large--1", "ligatus--medium--1", "layer--large--1", "layer--medium--1"
#
#
#
#
#     ];
#     var xfp_ads = {
#         "top" : {
#             "large" : [ [ 970, 250 ], [ 970, 120 ], [ 970, 90 ], [ 728, 90 ] ],
#             "medium" : [ [ 728, 90 ] ],
#             "small" : [ [ 320, 100 ] , [ 320, 50 ] ]
#         },
#         "mid1" : {
#             "large" : [ [ 300 , 600 ] ],
#             "medium" : [ [ 300 , 600] ],
#             "small" : [ [ 320, 250 ], [ 300, 250 ] ]
#         },
#         "mid2" : {
#             "large" : [ [ 300, 250 ] ],
#             "medium" : [ [ 300, 250 ] ],
#             "small" : []
#         },
#         "aankeiler" : {
#             "large" : [ [ 300, 292 ] ],
#             "medium" : [ [ 300, 292 ] ],
#             "small" : [ [ 300, 292 ] ]
#         },
#         "layer" : {
#             "large" : [ [ 640, 480 ] ],
#             "medium" : [ [ 1024, 768 ], [ 640, 480 ] ],
#             "small" : [ [ 320, 480 ] ]
#         },
#         "marketing1" : {
#             "large" : [ [ 352, 140 ] ],
#             "medium" : [ [ 352, 140 ] ],
#             "small" : []
#         },
#         "marketing2" : {
#             "large" : [ [ 300, 250 ] ],
#             "medium" : [ [ 728, 90 ] ],
#             "small" : []
#         },
#         "aanbieding": {
#             "large" : [ [ 299, 138 ] ],
#             "medium" : [ [ 299, 138 ] ],
#             "small" : [ [ 299, 138 ] ]
#         },
#         "rectangle": {
#             "large" : [ [ 300, 250 ] ],
#             "medium" : [ [ 300, 250 ] ],
#             "small" : [ [ 300, 250 ] ]
#         },
#         "ligatus": {
#             "large" : [ [ 600, 250 ] ],
#             "medium" : [ [ 600, 250 ] ],
#             "small" : [ [ 600, 250 ] ]
#         }
#     };
#
#     var ssoUrl="https://caps.volkskrant.nl";
#     var ssoService="/service";
#     var login={'url':'http://www.volkskrant.nl/user/loggedIn.do', 'id':'caps-vk-1201'};
#     var paywall={'url':'http://www.volkskrant.nl/user/paywall.do', 'id':'caps-vk-1202'};
#     var comment={'url':'http://www.volkskrant.nl/user/reaction.do','id':'caps-vk-1203'};
#
#     var userdataUrl="http://www.volkskrant.nl/json/userdata.do";
#     var statisticsUrl = "http://stats.persgroep.nl/statistics.js";
#
#
#
#
#
#     function slotRenderEndedCallback(id, empty, size) {
#         var elm = document.getElementById(id);
#         if(elm){
#             if(empty){
#                 elm.className = elm.className + " js-is-empty";
#             } else {
#                 elm.className = elm.className + " js-is-not-empty";
#                 elm.style.width = size[0] + 'px';
#             }
#         }
#     };
#
#     function hasClass(elm, className) {
#         return elm.className.match(new RegExp('(\\s|^)' + className + '(\\s|$)'));
#     }
#
#     function removeClass(elm, className) {
#         if (hasClass(elm,className)) {
#             var reg = new RegExp('(\\s|^)' + className + '(\\s|$)');
#             elm.className = elm.className.replace(reg, ' ');
#         }
#     }
#
#     function addClass(elm, className) {
#         if (!this.hasClass(elm, className)) elm.className += " " + className;
#     }
#
#     function dimensionChangeCallback(originalDisplay) {
#         var html = document.getElementsByTagName("html")[0],
#             className = "js-no-ads";
#
#         if(originalDisplay){
#             removeClass(html, className);
#         } else {
#             addClass(html, className);
#         }
#     }
#
#     DART.init({
#         'breakpoints': {767: 'small', 1023: 'medium', 1500: 'large'},
#         'onDimensionChange': dimensionChangeCallback,
#         'onSlotRenderEnded': slotRenderEndedCallback
#     });
#
#
#     DART.initializeGoogleAds({
#         'tagPrefix': '/7594/vk/vk.site-' + DART.returnDevice() + '/',
#         'ads': xfp_ads,
#         'positions': xfp_posities,
#         'pageType': 'articleDetail',
#
#         'compId': '3852007',
#
#
#         'nodeIds': [2099],
#
#         'hyperdistribution': false,
#         'levels': pe_adsLevels,
#         'navType': pe_navType
#     });
#
#
#
#
#     var _utsp = {};
#     var _utsc = _utsc || [];
#     _utsp.host = 'http://utsdpn.persgroep.net/';
#     _utsp.sslHost = 'https://utsdpn.persgroep.net/:443';
#     _utsp.vea_mode = 'disable';
#     (function() {
#         var uts = document.createElement('script');
#         uts.type = 'text/javascript';
#         uts.async = true;
#         uts.src = ('https:' == document.location.protocol ? _utsp.sslHost : _utsp.host) + '/uts-static/uts-no-vea.min.js';
#         var s = document.getElementsByTagName('script')[0];
#         s.parentNode.insertBefore(uts, s);
#     })();
#
#
#
#
# dataLayer = [{'ua_usageType' : 'PAYED',
# 'ua_navigation' : 'economie',
# 'ua_accessType' : 'PAYWALL',
# 'ua_assetAuthor' : 'Peter de Waard',
# 'ua_numberOfChars' : '848',
# 'ua_brandID' : '2001',
# 'ua_pageType' : 'detail',
# 'ua_assetType' : 'DEFAULT ARTICLE',
# 'ua_contentID' : '3852007',
# 'ua_assetPublicationDate' : '1424034600',
# 'ua_navigationID' : '20007'}];
#
#
#
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-KX8PFJ');
#
#
#
#
#
#
#
#
#
#
# 	if ( DART.returnDevice() === "large" ){
#     	DART.showGoogleAd( "top--large--1" );
#     }
#
#
#
#
# 	if ( DART.returnDevice() === "medium" ){
#     	DART.showGoogleAd( "top--medium--1" );
#     }
#
#
#
#
#
# De Volkskrant
#
#
# Economie
#
#
#
#
#
#
#
#
# Navigatie
#
# Gratis proberen
#
#
# Nieuws
#
#
#
# Voorpagina
#
#
#
#
#
#
#
#
#
# 'Video IS toont onthoofding 21 koptische christenen'
#
#
#
#
# 101
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             101  +
#               +
#               =
#             101
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
# Dader Kopenhagen was 22-jarige Deen
#
#
#
#
# 107
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             107  +
#               +
#               =
#             107
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
# KNMI waarschuwt voor gladheid in de nacht en morgenochtend
#
#
#
#
# 21
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             21  +
#               +
#               =
#             21
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# De man die de wereld aan de Nutella bracht
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#                             Economie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Waarom is één biertje nooit genoeg?
#
#
#
#
# 55
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             55  +
#             0  +
#             0  =
#             55
#
#
#
#
#
#
#                             Wetenschap
#
#
#
#
#
#
#
#
#
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
# 'Video IS toont onthoofding 21 koptische christenen'
#
#
#
#
# 101
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             101  +
#               +
#               =
#             101
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
# Dader Kopenhagen was 22-jarige Deen
#
#
#
#
# 107
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             107  +
#               +
#               =
#             107
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
# Cartoonist Vilks: 'Ik was het doelwit maar ik laat me niet bang maken'
#
#
#
#
# 26
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             26  +
#               +
#               =
#             26
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Tot twee keer toe weet dader te ontsnappen in Kopenhagen
#
#
#
#
# 24
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             24  +
#             0  +
#             0  =
#             24
#
#
#
#
#
#
#                             Buitenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Feministische pornomaakster bekritiseert 50 shades
#
#
#
#
# 19
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             19  +
#             0  +
#             0  =
#             19
#
#
#
#
#
#
#                             Leven
#
#
#
#
#
#
#
#
#
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
# Nederlandse trainers in Irak gestart
#
#
#
#
# 19
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             19  +
#               +
#               =
#             19
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
# KNMI waarschuwt voor gladheid in de nacht en morgenochtend
#
#
#
#
# 21
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             21  +
#               +
#               =
#             21
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
# Deskundigen eisen verbod op 'kidsmarketing'
#
#
#
#
# 121
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             121  +
#               +
#               =
#             121
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Kramer onttroont Bergsma met wereldrecord op laaglandbaan
#
#
#
#
# 8
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             8  +
#             0  +
#             0  =
#             8
#
#
#
#
#
#
#                             Binnenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Gaswinning loopt op zijn einde. En iedereen weet het
#
#
#
#
# 78
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             78  +
#             0  +
#             0  =
#             78
#
#
#
#
#
#
#                             Opinie
#
#
#
#
#
#
#
#
#
#
#
#
# Opinie
#
#
#
#
#
#
#
#
#
# Geest van wraakzuchtig revisionisme is uit de fles
#
#
#
#
# 30
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#             20  +
#               =
#             30
#
#
#
#
# Dirk-Jan van Baar
#
#
#
#
#
#
#
#
#
# 'Dekker creëert markt voor ideologen, aasgieren en Jomanda's'
#
#
#
#
# 40
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             25  +
#             15  +
#               =
#             40
#
#
#
#
# Opinie
#
#
#
#
#
#
#
#
#
# Moslima's, wees niet telkens zo snel beledigd
#
#
#
#
# 211
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             145  +
#             66  +
#               =
#             211
#
#
#
#
# Opinie
#
#
#
#
#
#
#
#
#
#
#
#
# Gastcolumn Geerten Waling
#
#
#
#
#
#
#
#
#
# 188
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             166  +
#             22  +
#             0  =
#             188
#
#
#
#
#  COLUMN
#
#
#
#
#
#
#
#
# De Betrouwbare Mannetjes
#
#
# MelleRunderkamp
#
#
#
#
#
# 19
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             19  +
#             0  +
#             0  =
#             19
#
#
#
#
#  COLUMN
#
#
#
#
#
#
#
#
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
# 'Hackers sluisden tientallen miljoenen van banken weg'
#
#
#
#
# 37
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             37  +
#               +
#               =
#             37
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
# Air France-KLM ontkent 'sloop' KLM
#
#
#
#
# 18
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             18  +
#               +
#               =
#             18
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
# Tsipras: Griekenland heeft tijd nodig, geen geld
#
#
#
#
# 39
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             39  +
#               +
#               =
#             39
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# De man die de wereld aan de Nutella bracht
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#                             Economie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Van weggegooid eten kun je leuk op vakantie
#
#
#
#
# 20
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             20  +
#             0  +
#             0  =
#             20
#
#
#
#
#
#
#                             Economie
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sport
#
#
#
#
#
#
#
#
#
# Ajax knokt zich in enerverend duel langs FC Twente
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#               +
#               =
#             0
#
#
#
#
# Eredivisie
#
#
#
#
#
#
#
#
#
# Zilver voor debutante Achtereekte, Sablikova pakt goud
#
#
#
#
# 5
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             5  +
#               +
#               =
#             5
#
#
#
#
# Sport
#
#
#
#
#
#
#
#
#
# Inzet Veltman onzeker voor duel met Legia
#
#
#
#
# 3
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             3  +
#               +
#               =
#             3
#
#
#
#
# Sport
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Kramer onttroont Bergsma met wereldrecord op laaglandbaan
#
#
#
#
# 8
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             8  +
#             0  +
#             0  =
#             8
#
#
#
#
#
#
#                             Binnenland
#
#
#
#
#
#
#
#
#
#
# De Twaalfde Man Paul
#
#
# PaulOnkenhout
#
#
#
#
#
# 6
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             5  +
#             1  +
#             0  =
#             6
#
#
#
#
#  COLUMN
#
#
#
#
#
#
#
#
#
#
#
#
# Tech
#
#
#
#
#
#
#
#
#
# 'Hackers sluisden tientallen miljoenen van banken weg'
#
#
#
#
# 37
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             37  +
#               +
#               =
#             37
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
# 'Apple werkt aan elektrische auto'
#
#
#
#
# 12
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             12  +
#               +
#               =
#             12
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
# Obama wil meer actie tegen cyberaanvallen
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#               +
#               =
#             2
#
#
#
#
# Tech
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# De Drie Apps van de Week: Limbo, Evoland en Blendle Trending
#
#
#
#
# 6
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             6  +
#             0  +
#             0  =
#             6
#
#
#
#
#
#
#                             Tech
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Game-pc vermomd als spelcomputer
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
#
#                             Tech
#
#
#
#
#
#
#
#
#
#
#
#
#
# Media
#
#
#
#
#
#
#
#
#
# 'NOS mijdt ouderenthema's tijdens verkiezingsdebat'
#
#
#
#
# 12
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             12  +
#               +
#               =
#             12
#
#
#
#
# Politiek
#
#
#
#
#
#
#
#
#
# 'Nederland op vijfde plek met bijna miljoen Netflix-abonnees'
#
#
#
#
# 31
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             31  +
#               +
#               =
#             31
#
#
#
#
# Media
#
#
#
#
#
#
#
#
#
# CEO's bedanken voor Obama's cybertop
#
#
#
#
# 11
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             11  +
#               +
#               =
#             11
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Casual Vacancy, Het Groot-Brittannië van..., The Genius of Photography
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#                             Televisie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Groenland, Lincoln, Winter's Bone
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#                             Televisie
#
#
#
#
#
#
#
#
#
#
#
#
# Wetenschap
#
#
#
#
#
#
#
#
#
# VS staan genetisch gemodificeerde appels toe
#
#
#
#
# 11
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             11  +
#               +
#               =
#             11
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
# Schippers over kritiek PvdA-senator: zorgstelsel wel solidair
#
#
#
#
# 24
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             24  +
#               +
#               =
#             24
#
#
#
#
# Zorg
#
#
#
#
#
#
#
#
#
# Gigantische ijsvlakte Antarctica staat op breken
#
#
#
#
# 483
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             483  +
#               +
#               =
#             483
#
#
#
#
# Wetenschap
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Waarom is één biertje nooit genoeg?
#
#
#
#
# 55
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             55  +
#             0  +
#             0  =
#             55
#
#
#
#
#
#
#                             Wetenschap
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Pompgemak
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#                             Wetenschap
#
#
#
#
#
#
#
#
#
#
#
#
#
# Politiek
#
#
#
#
#
#
#
#
#
# Zijlstra: kans op meer gaswinning heel klein
#
#
#
#
# 19
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             19  +
#               +
#               =
#             19
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
# 'NOS mijdt ouderenthema's tijdens verkiezingsdebat'
#
#
#
#
# 12
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             12  +
#               +
#               =
#             12
#
#
#
#
# Politiek
#
#
#
#
#
#
#
#
#
# Veertig landen bijeen op conferentie VN-vredesmissies in Amsterdam
#
#
#
#
# 1
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             1  +
#               +
#               =
#             1
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Binnenhof staat voor 'grootste volksverhuizing ooit'
#
#
#
#
# 6
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             6  +
#             0  +
#             0  =
#             6
#
#
#
#
#
#
#                             Binnenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# De echte strijd om het gas komt nog
#
#
#
#
# 14
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             14  +
#             0  +
#             0  =
#             14
#
#
#
#
#
#
#                             Binnenland
#
#
#
#
#
#
#
#
#
#
#
#
#
# Specials
#
#
# Cartoons
#
#
# Foto
#
#
# Vonk
#
#
# Dag In Dag uit
#
#
#
#
#
# Cultuur &
#                 Leven
#
#
#
# Voorpagina
#
#
#
#
#
#
#
#
#
# Bioscopen beleven beste Valentijnsdag ooit
#
#
#
#
# 23
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             23  +
#               +
#               =
#             23
#
#
#
#
# Film
#
#
#
#
#
#
#
#
#
# Faithless kondigt reünie aan
#
#
#
#
# 133
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             133  +
#               +
#               =
#             133
#
#
#
#
# Muziek
#
#
#
#
#
#
#
#
#
# Nederlandse korte animatiefilm genomineerd voor Oscar
#
#
#
#
# 35
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             35  +
#               +
#               =
#             35
#
#
#
#
# Oscars
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fotograaf Erwin Olaf: 'Ik heb lang genoeg het majorettekorps aangevoerd'
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#             0  +
#             0  =
#             10
#
#
#
#
#
#
#                             Leven
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Niets-aan-de-handkunst uit een foute periode
#
#
#
#
# 4
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             4  +
#             0  +
#             0  =
#             4
#
#
#
#
#
#
#                             Beeldende Kunst
#
#
#
#
#
#
#
#
#
#
#
#
#
# Agenda
#
#
# Recensies
#
#
#
#
#
#
#
#
#
# Vrolijkmakende popliedjes in jarenvijftigsfeer
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#               +
#               =
#             0
#
#
#
#
# Muziek
#
#
#
#
#
#
#
#
#
# Kunstmusea opnieuw de les gelezen met advertentie
#
#
#
#
# 5
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#               +
#             3  =
#             5
#
#
#
#
# musea en galerieën
#
#
#
#
#
#
#
#
#
# 'Troostmeisjes' van Nederlandse fotograaf Banning nu ook te zien in Japan
#
#
#
#
# 7
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             3  +
#               +
#             4  =
#             7
#
#
#
#
# Agenda
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	                De condition humaine is een...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Edward O. Wilson
# The meaning of human existence
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
# 	                        Non-fictie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Huiveringwekkend bankiersportret
# Vol humor en zelfreflectie...
#
#
#
#
# 173
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             173  +
#             0  +
#             0  =
#             173
#
#
#
#
#
# Boeken
#
#
#
#
#
#
#
#
#
#
#
# Film
#
#
#
#
#
#
#
#
#
# Nederlandse korte animatiefilm genomineerd voor Oscar
#
#
#
#
# 35
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             35  +
#               +
#               =
#             35
#
#
#
#
# Oscars
#
#
#
#
#
#
#
#
#
# Bioscopen beleven beste Valentijnsdag ooit
#
#
#
#
# 23
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             23  +
#               +
#               =
#             23
#
#
#
#
# Film
#
#
#
#
#
#
#
#
#
# Zuid-Amerika favoriet in Berlijn
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#               +
#               =
#             2
#
#
#
#
# Film
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# De film die 'Fifty shades' preuts maakt
#
#
#
#
# 5
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             5  +
#             0  +
#             0  =
#             5
#
#
#
#
#
#
#                             Film
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Forbidden Zone
#
#
#
#
#                             Theater
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Muziek
#
#
#
#
#
#
#
#
#
# Visage-zanger Steve Strange (55) overleden
#
#
#
#
# 9
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             9  +
#               +
#               =
#             9
#
#
#
#
# Muziek
#
#
#
#
#
#
#
#
#
# Paradiso begint eigen platenlabel
#
#
#
#
# 113
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             113  +
#               +
#               =
#             113
#
#
#
#
# Muziek
#
#
#
#
#
#
#
#
#
# Faithless komt na vier jaar alweer samen
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#               +
#               =
#             10
#
#
#
#
# Muziek
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# De beste muziek van de week (7): Father John Misty, Herman Brock Jr. en Gretchen Peters
#
#
#
#
# 4
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             4  +
#             0  +
#             0  =
#             4
#
#
#
#
#
#
#                             Muziek
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Paloma Faith een bitch? Nee, een heerlijke meid
#
#
#
#
# 15
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             15  +
#             0  +
#             0  =
#             15
#
#
#
#
#
#
#                             Muziek
#
#
#
#
#
#
#
#
#
#
#
#
# Reizen
#
#
#
#
#
#
#
#
#
# Snelweg van Lille naar Parijs weer open
#
#
#
#
# 30
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             30  +
#               +
#               =
#             30
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
# Eerste verre bestemming Eindhoven Airport
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#               +
#               =
#             10
#
#
#
#
# Reizen
#
#
#
#
#
#
#
#
#
# Weer toeriste verkracht in India, politie zoekt verdachte 'gids'
#
#
#
#
# 11
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             11  +
#               +
#               =
#             11
#
#
#
#
# Reizen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Buitenzwemmen onder alle omstandigheden
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#                             Reizen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Coolest Cooler: de succesvolste Kickstartercampagne ooit
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#                             Reizen
#
#
#
#
#
#
#
#
#
#
#
#
# Koken & Eten
#
#
#
#
#
#
#
#
#
# Antibioticaresistente bacteriën op helft van vis en garnalen
#
#
#
#
# 1
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#               +
#             1  =
#             1
#
#
#
#
# Koken & Eten
#
#
#
#
#
#
#
#
#
# VS staan genetisch gemodificeerde appels toe
#
#
#
#
# 11
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             11  +
#               +
#               =
#             11
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
# Vitamines geven chemieconcern DSM hoofdpijn
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#               +
#               =
#             0
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 'Bier en psychiatrie, dat gaat toch niet samen?'
#
#
#
#
# 19
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             19  +
#             0  +
#             0  =
#             19
#
#
#
#
#
#
#                             Koken & Eten
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Vandeijck
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
# 	                        Restaurant
#
#
#
#
#
#
#
#
#
#
#
#
# Theater
#
#
#
#
#
#
#
#
#
# Victor Löw en Halina Reijn genomineerd voor belangrijkste toneelprijzen
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#               +
#               =
#             10
#
#
#
#
# Theater
#
#
#
#
#
#
#
#
#
# Films van 'legendarische' theatervoorstellingen in digitale filmbank
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#               +
#               =
#             10
#
#
#
#
# Theater
#
#
#
#
#
#
#
#
#
# Geen 'Konzertsaal' in München
#
#
#
#
# 1
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             1  +
#               +
#               =
#             1
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fotograaf Erwin Olaf: 'Ik heb lang genoeg het majorettekorps aangevoerd'
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#             0  +
#             0  =
#             10
#
#
#
#
#
#
#                             Leven
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Chuck en Charlene
#
#
#
#
#                             Jeugd
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Boeken
#
#
#
#
#
#
#
#
#
# Israëlische schrijvers woedend over bemoeienis Netanyahu met Israël Prijs
#
#
#
#
# 27
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             27  +
#               +
#               =
#             27
#
#
#
#
# Israëlisch-Palestijns conflict
#
#
#
#
#
#
#
#
#
# De Avonden van Gerard Reve krijgt Engelse vertaling
#
#
#
#
# 26
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             26  +
#               +
#               =
#             26
#
#
#
#
# Boeken
#
#
#
#
#
#
#
#
#
# Hannelore Grünberg-Klein (87), moeder Arnon Grunberg, overleden
#
#
#
#
# 76
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             76  +
#               +
#               =
#             76
#
#
#
#
# Boeken
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fotograaf Erwin Olaf: 'Ik heb lang genoeg het majorettekorps aangevoerd'
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#             0  +
#             0  =
#             10
#
#
#
#
#
#
#                             Leven
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	                De condition humaine is een...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Edward O. Wilson
# The meaning of human existence
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
# 	                        Non-fictie
#
#
#
#
#
#
#
#
#
#
#
# Beeldende Kunst
#
#
#
#
#
#
#
#
#
# Schotse kunst ging kelder in
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#               +
#               =
#             0
#
#
#
#
# musea en galerieën
#
#
#
#
#
#
#
#
#
# 'World Press Photo wordt denktank'
#
#
#
#
# 14
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             14  +
#               +
#               =
#             14
#
#
#
#
# Tech
#
#
#
#
#
#
#
#
#
# Elektricien Picasso voor heling voor rechter
#
#
#
#
# 12
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             12  +
#               +
#               =
#             12
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fotograaf Erwin Olaf: 'Ik heb lang genoeg het majorettekorps aangevoerd'
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#             0  +
#             0  =
#             10
#
#
#
#
#
#
#                             Leven
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Niets-aan-de-handkunst uit een foute periode
#
#
#
#
# 4
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             4  +
#             0  +
#             0  =
#             4
#
#
#
#
#
#
#                             Beeldende Kunst
#
#
#
#
#
#
#
#
#
#
#
#
#
# Leven
#
#
# Mode & Mooi
#
#
# Festivals
#
#
# Televisie
#
#
# Voordeel
#
#
#
#
#
#
#
#
#
# Gebruikersnavigatie
#
#
#
# Gebruikersnavigatie
#
#
#
#   Zoeken
#
#
#
#
#
#
# Zoeken
#
#
#
#
#
#
#
#
#
#
#  Mijn nieuws
#  Ik volg
#  Lees later
#
#
#
#
#                             Uitloggen
#
#
#
#                             Account
#
#
#
#
#
#                             Account
#
#
#
#                             Uitloggen
#
#
#
#
#
#
#
#
#
#
#
# Mijn nieuws
#
#
#
#
#  Ik volg
#
#
#
#
#  Lees later
#
#
#
#
#  Uitloggen
#
#
#                         Account
#
#
#
#
#
#  Inloggen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Weer
#
#
#
#
#
# Beurs
#
#
# Banen
#
#
#
#
#
#
# Abonneer
# Digitale krant
# Service
# Winkel
# Voordeel
#
#
#
#
#
#
#
#
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
# Deel
#
#
# Deel dit artikel via
#
#
#
#
#
#
#
# 2
#
#
#                                             Twitter
#
#
#
#
#
#
#
#
#
# 0
#
#
#                                             Facebook
#
#
#
#
#
#
#
#
#
# 0
#
#
#                                             Linkedin
#
#
#
#
#
#
#
#
#
# 0
#
#
#                                             Google +
#
#
#
#
#
#
#
#
#
# 0
#
#
#                                             E-mail
#
#
#
#
#
#
# 2
#
#
#
#
#
#
#
# Deel
#
#
#
# 2
#
#
#
#
#
#
#
#
# Bewaar
#
#
#
#
# 0
#
#
#
#
#
# Bewaar
#
#
#
# 0
#
#
#
#
#
# Bewaar
#
#
#
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	if ( DART.returnDevice() === "small" ){
#     	DART.showGoogleAd( "top--small--1" );
#     }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Michele Ferrero (m) tijdens de uitvaart van zijn zoon in 2011.
# © EPA
#
#
#
#
# De man die de wereld aan de Nutella bracht
#
#
#
#
#
#
#
#
#                 Postuum
#
#
#
#
#
#                     Het is surrogaatchocola, maar doe het in een luxe ogende pot en de hele wereld eet het. 'Mister Nutella' werd er de rijkste Italiaan mee.
#
#
#
#
#
# Door: Peter de Waard
#
# 15 februari 2015, 22:10
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#
#
#
#
#
# Vorige maand verbood een rechter in Frankrijk nog een echtpaar hun
# dochter te vernoemen naar 's werelds favoriete broodbeleg Nutella.
# Ze moesten het met Ella doen. Het tekent hoe geliefd de
# chocoladepasta wereldwijd is. Jaarlijks wordt er in 160 landen 360
# miljoen kilo van geconsumeerd .
#
#
#  Afgelopen weekeinde overleed 'Mister Nutella', de Italiaanse
# industrieel Michele Ferrero, wiens bedrijf Ferrero SpA ook de
# bonbons Mon Chéri, Ferrero Rocher, de chocoladeverrassingen
# Kinder en het frisse ademsnoepje Tic Tac op de markt brengt.
#
#
#
#
#
#
#
#
# Hazelnoten
#
#
# Ferrero zal worden begraven in Alba, in de noordwestelijke
# Italiaanse streek Piëmont waar hij vandaan komt en waar een
# museum aan de producten is gewijd.
#
#
#
#
#
#
#
#
#
#
#
#
# Onbeperkte toegang?
# Probeer nu geheel gratis via web, mobiel en apps
#
#
#
#
# Geen abonnee?
# Gratis proberen
#
#
# Abonnee?
# Krijg direct toegang
#
#
# Abonnee?
#
# 					Login
#
#
#
#
# Geen abonnee?
# Ja, ik wil graag toegang
#
#
# Abonnee?
# Krijg direct toegang
#
#
#
#
#
# Alles van de Volkskrant
# Complete cultuuragenda
# Stel uw Volkskrant samen
# Deel favoriete artikelen
# De mooiste fotografie
#
#  Lees meer
#
#
#
#
# 			  Gratis proberen
#
# 			  Ja, ik wil graag toegang
#
#
#
#
#
#
#
#
#
#
#
# Sidebar
#
#
#
#
#
#
#
#
#
#
#
#                     Gerelateerde artikelen
#
#
#
#
#
#
#
#
#
#
# VS staan genetisch gemodificeerde appels toe
#
#
#
# 15 feb 2015
#
#
#
#
#
#
#
#
#
# 'Vader' van broodbeleg Nutella overleden
#
#
#
# 14 feb 2015
#
#
#
#
#
#
#
#
#
# 'Nauwelijks meer werkenden door lagere belasting'
#
#
#
# 14 feb 2015
#
#
#
#
#
#
#
#
#
#
#
# 	if ( DART.returnDevice() === "large" ){
#     	DART.showGoogleAd( "mid--large--1" );
#     }
#
#
#
#
#
# Meest gelezen Economie
#
#
#
#
#
# 1
#  46454
#
#
#
#
#
# V&D voorlopig gered van faillissement
#
#
#
# Economie
#
#
#
#
#
#
#
#
# 2
#  37655
#
#
#
#
#
# Eerlijk betaald? Het is tijd om te benoemen wat misgaat, niet wat goed gaat
#
#
#
# Koken & Eten
#
#
#
#
#
#
#
#
# 3
#  30941
#
#
#
#
#
# 'Alleen babymelkpoeder kopen verboden bij Jumbo'
#
#
#
# Economie
#
#
#
#
#
#
#
#
# 4
#  24351
#
#
#
#
#
# Albert Heijn teruggefloten om 'kristalglas'
#
#
#
# Economie
#
#
#
#
#
#
#
#
# 5
#  22043
#
#
#
#
#
# Griekse banken lopen leeg, ECB verstrekt extra krediet
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
#  Bekijk hele lijst
#
#
#
#
#
# 		if ( DART.returnDevice() === "large" ){
# 			DART.showGoogleAd( "rectangle--large--1" );
# 		}
#
#
#
#
#
#
#
#
#
#
#
# 	if ( DART.returnDevice() === "small" ){
#     	DART.showGoogleAd( "mid--small--1" );
#     }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Verder in Nieuws
#
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
# Tot twee keer toe weet dader te ontsnappen in Kopenhagen
#
#
#
#
# 24
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             24  +
#             0  +
#             0  =
#             24
#
#
#
#
#
#
#                             Buitenland
#
#
#
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
# Kramer onttroont Bergsma met wereldrecord op laaglandbaan
#
#
#
#
# 8
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             8  +
#             0  +
#             0  =
#             8
#
#
#
#
#
#
#                             Binnenland
#
#
#
#
#
#
#
#
# Opinie
#
#
# Stekel
#
#
# Sandervan Walsum
#
#
#
#
#
# 4
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             3  +
#             1  +
#             0  =
#             4
#
#
#
#
#  COLUMN
#
#
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
# Particuliere ov-bedrijven proberen monopolie NS te breken
#
#
#
#
# 16
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             16  +
#             0  +
#             0  =
#             16
#
#
#
#
#
#
#                             Economie
#
#
#
#
#
#
#
#
# Sport
#
#
#
#
#
#
#
#
#
# Max Verstappen is geboren om te racen
#
#
#
#
# 17
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             17  +
#             0  +
#             0  =
#             17
#
#
#
#
#
#
#                             Sport
#
#
#
#
#
#
#
#
# Tech
#
#
#
#
#
#
#
#
#
# De Drie Apps van de Week: Limbo, Evoland en Blendle Trending
#
#
#
#
# 6
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             6  +
#             0  +
#             0  =
#             6
#
#
#
#
#
#
#                             Tech
#
#
#
#
#
#
#
# Media
#
#
#
#
#
#
#
#
#
# Als ik wil twitteren denk ik: Oude trut, bemoei je er niet mee
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#             0  +
#             0  =
#             10
#
#
#
#
#
#
#                             Media
#
#
#
#
#
#
#
#
# Wetenschap
#
#
#
#
#
#
#
#
#
# Pompgemak
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#                             Wetenschap
#
#
#
#
#
#
#
#
# Politiek
#
#
#
#
#
#
#
#
#
# #binnenskamers: kabinet stuurt nieuws MH17 retour
#
#
#
#
# 102
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             102  +
#             0  +
#             0  =
#             102
#
#
#
#
#
#
#                             Politiek
#
#
#
#
#
#
#
# Vonk
#
#
#
#
#
#
#
#
#
# Met bevende handen veegde ik mijn tranen weg
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
#
#                             Vonk
#
#
#
#
#
#
#
# Televisie
#
#
#
# Logeren
#
# Voor Chantal moet Expeditie Robinson een eitje zijn
#
#
#
# AafBrandt Corstius
#
#
#
#
# 1
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             1  =
#             1
#
#
#
#
#  COLUMN
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Verder in Cultuur & Leven
#
#
#
#
#
# Recensies
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Karen Dawisha beschrijft corrupt regime van Poetin verbluffend nauwkeurig
# Inktzwart beeld van Poetins...
#
#
#
#
# 12
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             11  +
#             1  +
#             0  =
#             12
#
#
#
#
#
# Recensies
#
#
#
#
#
#
# Film
#
#
#
#
#
#
#
#
#
# De film die 'Fifty shades' preuts maakt
#
#
#
#
# 5
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             5  +
#             0  +
#             0  =
#             5
#
#
#
#
#
#
#                             Film
#
#
#
#
#
#
#
#
# Muziek
#
#
#
#
#
#
#
#
#
# Paloma Faith een bitch? Nee, een heerlijke meid
#
#
#
#
# 15
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             15  +
#             0  +
#             0  =
#             15
#
#
#
#
#
#
#                             Muziek
#
#
#
#
#
#
#
# Reizen
#
#
#
#
#
#
#
#
#
# Buitenzwemmen onder alle omstandigheden
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#                             Reizen
#
#
#
#
#
#
#
#
# Koken & Eten
#
#
#
#
#
#
#
#
#
# 'Bier en psychiatrie, dat gaat toch niet samen?'
#
#
#
#
# 19
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             19  +
#             0  +
#             0  =
#             19
#
#
#
#
#
#
#                             Koken & Eten
#
#
#
#
#
#
#
#
# Theater
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Forbidden Zone
#
#
#
#
#                             Theater
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#
#
#
#
# Boeken
#
#
#
#
#
# 	                De condition humaine is een...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Edward O. Wilson
# The meaning of human existence
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
# 	                        Non-fictie
#
#
#
#
#
#
# Beeldende Kunst
#
#
#
#
#
#
#
#
#
# Niets-aan-de-handkunst uit een foute periode
#
#
#
#
# 4
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             4  +
#             0  +
#             0  =
#             4
#
#
#
#
#
#
#                             Beeldende Kunst
#
#
#
#
#
#
#
#
# Leven
#
#
#
#
#
#
#
#
#
# Feministische pornomaakster bekritiseert 50 shades
#
#
#
#
# 19
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             19  +
#             0  +
#             0  =
#             19
#
#
#
#
#
#
#                             Leven
#
#
#
#
#
#
#
#
# Mode & Mooi
#
#
#
#
#
#
#
#
#
# In de winkel
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
#
#                             Mode & Mooi
#
#
#
#
#
#
#
#
# Festivals
#
#
#
#
#
#
#
#
#
# Gast van de Volkskrant Job de Wit: 'De programmeur van Le Guess Who? snapt het
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
#
#                             Festivals
#
#
#
#
#
#
#
# Televisie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Black Sails Seizoen 1
# Dvd-tip
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
# Televisie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Nieuws
#
#
# Economie
#
#
# De man die de wereld aan de Nutella bracht
#
#
#
#
#
#
#
#
#
# Nu bij de Volkskrant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Naar de winkel
#
#
#
#
#
#
#
#
#
#
#
#
# Twitter
#
#
#
#
#
# Facebook
#
#
#
#
#
# Google+
#
#
#
#
#
#
# Volg de Volkskrant
#
#
# Schrijf u in voor de dagelijkse nieuwsbrief
#
#
#
#
#
#
# Aanvragen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Archief
#
#
#
#
#
# Digitale krant
#
#
#
#
#
# Journalisten Columnisten
#
#
#
#
#
#
# Apps
#
#
# de Volkskrant
#
#
# de Volkskrant Original
#
#
# de Volkskrant Select
#
#
# Overzicht alle apps
#
#
#
#
#
#
#
# de Volkskrant
#
# Over de Volkskrant
# Auteursrecht & Privacy
# Vacatures
# Over deze website
# RSS feeds
#
#
#
#
#
# Service en contact
#
# Abonneren
# Service
# Veelgestelde vragen
# Contactgegevens
# Adverteren
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                         © 2015 - Alle rechten voorbehouden
# Lees de gebruiksvoorwaarden
#
#
#
#
#
#
#
#
#
#
# Nieuws
#
#
# Cultuur & Leven
#
#
#
#
#
#
#
#
#
#
#
#
#
# Weer
#
#
#
#
#
# Beurs
#
#
#
#
#
# Voorpagina
#
#
# Buitenland
#
#
# Binnenland
#
#
# Opinie
#
#
# Economie
#
#
# Sport
#
#
# Tech
#
#
# Media
#
#
# Wetenschap
#
#
# Politiek
#
#
# Specials
#
#
# Cartoons
#
#
# Foto
#
#
# Vonk
#
#
# Dag In Dag uit
#
#
# Abonnement
#
#
# Winkel
#
#
# Service
#
#
#
#
#
#
#
#
#
#
#
#
#
# Voorpagina
#
#
# Agenda
#
#
# Recensies
#
#
# Film
#
#
# Muziek
#
#
# Reizen
#
#
# Koken & Eten
#
#
# Theater
#
#
# Boeken
#
#
# Beeldende Kunst
#
#
# Leven
#
#
# Mode & Mooi
#
#
# Festivals
#
#
# Televisie
#
#
# Voordeel
#
#
# Abonnement
#
#
# Winkel
#
#
# Service
#
#
#
#
#
#
#
# Mijn Volkskrant
#
#
#
#
#  Mijn nieuws
#  Ik volg
#  Lees later
#  Account
#  Uitloggen
#   Inloggen
#
#
# Mijn nieuws
#
#
#
#
#  Ik volg
#
#
#
#
#  Lees later
#
#
#
#                 Account
#
#
#  Uitloggen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ©
#
# Tweets by @
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="//platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#
#
#
#
#
#
# 1
#
#
#
#
#
# Previous
# Next
#
#
#
#
#
#
#
#
#
# De Volkskrant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Deel dit
#
#
#
#
#
#
#
#
#
#
#                             Twitter
#
#
#
#
#
#
#
#
#
#
#
#
#                             Facebook
#
#
#
#
#
#
#
#
#
#
#
#
#                             Linkedin
#
#
#
#
#
#
#
#
#
#
#
#
#                             Google +
#
#
#
#
#
#
#
#
#
#
#
#
#                             E-mail
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# |
#
#
#
#
#
#
#
#
#
#
#
#
# U kunt deze maand nog 5/10 gedeelde VK-plus artikelen gratis lezen.
# Probeer VK-plus 2 weken gratis,zonder verplichtingen
#
#
# Gratis proberen
#
#
#
#                                     Al een account? Log in
#
#
#
# De Volkskrant biedt gratis en betaalde artikelen aan. Betaalde artikelen herkent u aan een VKplus label. Elke maand mag u gratis 10 VKplus artikelen lezen die uw vrienden met u delen.
#
#
#
#
#
# Alles van de Volkskrant
# Complete cultuuragenda
# Stel uw Volkskrant samen
# Deel favoriete artikelen
# De mooiste fotografie
#
#  Lees meer over VKplus?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# U heeft deze maand 5/10 gedeelde VK-plus artikelen gratis gelezen.
#
#
#
#
#
#
#
#
#
#
#
# Cookies op de Volkskrant
#
# Door gebruik te maken van deze website, of door op 'Akkoord' te klikken, geeft u toestemming voor het gebruik van cookies.
# De Volkskrant maakt gebruik van cookies, onder andere om de website te analyseren, het gebruiksgemak te vergroten en advertenties te tonen. Door gebruik te maken van deze website, of door op 'Akkoord' te klikken, geeft u toestemming voor het gebruik van cookies. Wilt u meer informatie over cookies en hoe ze worden gebruikt, bekijk dan ons cookiebeleid.
#
#
#
#
#
#  Akkoord
#
# Meer informatie
#
#
#
#
#
#
#
#
#
#
#         var _sf_async_config={};
#         /** CONFIGURATION START **/
#         _sf_async_config.uid = 46966;
# 	       _sf_async_config.domain = 'volkskrant.nl';
#         _sf_async_config.useCanonical = true;
#         _sf_async_config.sections = 'economie'; //CHANGE THIS
#         _sf_async_config.authors = 'Peter de Waard';
#         /** CONFIGURATION END **/
#         (function(){
#             function loadChartbeat() {
#                 window._sf_endpt=(new Date()).getTime();
#                 var e = document.createElement('script');
#                 e.setAttribute('language', 'javascript');
#                 e.setAttribute('type', 'text/javascript');
#                 e.setAttribute('src', '//static.chartbeat.com/js/chartbeat.js');
#                 document.body.appendChild(e);
#                 }
#                 var oldonload = window.onload;
#                 window.onload = (typeof window.onload != 'function') ?
#                 loadChartbeat : function()
#                 { oldonload(); loadChartbeat(); }
#                 ;
#         })();
#
#
#
#
#
#
# 	if ( DART.returnDevice() === "large" ){
#     	DART.showGoogleAd( "layer--large--1" );
#     }
#
#
#
#
# 	if ( DART.returnDevice() === "medium" ){
#     	DART.showGoogleAd( "layer--medium--1" );
#     }
