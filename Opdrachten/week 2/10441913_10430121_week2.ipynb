# %% [markdown]
# ## RSS parsing
#
# Make a notebook that performs the following steps.
#
#     1. Create a script that retrieves all urls of rss feeds from http://www.volkskrant.nl/nl/2764/rss/integration/nmc/frameset/footer/rss/rssFeeds.dhtml. Use urllib2 and beautifulsoup for this. Store the urls in a list.
#
#     2. Download all rss feeds and store them on disk.
#
#     3. Parse all RSS feeds using lxml. Create a list of dicts with fields "channel", "url", "title", "date" in which you store this information for each item.
#
#     4. Compute some statistics about this dict: how many items, how many per channel, are there doubles (items occuring in several channels), etc.
#
#     5. Write this list as a csv file, store on disk, and upload to Google fusion tables.
#
#     6. Download all articles (once), parse out the text and store as pairs (date,text) in a list.
#
#     7. Count per day the number of words, and the number of unique words. Show this in a plot.

# %%
try:
    from cStringIO import StringIO
except:
    from StringIO import StringIO
import codecs
import csv
    
class UnicodeWriter:
    """
    A CSV writer which will write rows to CSV file "f",
    which is encoded in the given encoding. Heavily based
    on the stackoverflow solution posted here:
    
    http://stackoverflow.com/questions/3085263/create-an-utf-8-csv-file-in-python
    """

    def __init__(self, f, dialect=csv.excel, encoding="utf-8", **kwds):
        # Redirect output to a queue
        self.queue = StringIO()
        self.writer = csv.writer(self.queue, dialect=dialect, **kwds)
        self.stream = f
        self.encoder = codecs.getincrementalencoder(encoding)()

    def writerow(self, row):
        self.writer.writerow([s.encode("utf-8") for s in row])
        # Fetch UTF-8 output from the queue ...
        data = self.queue.getvalue()
        data = data.decode("utf-8")
        # ... and reencode it into the target encoding
        data = self.encoder.encode(data)
        # write to the target stream
        self.stream.write(data)
        # empty queue
        self.queue.truncate(0)

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)

# %%
import urllib2
from bs4 import BeautifulSoup
from bs4 import UnicodeDammit
from lxml import etree
from lxml import objectify

# 1.1
url="http://static3.volkskrant.nl/static/nmc/nmc/frameset/footer/rss/rssFeeds.html?language=nl&pageType=integration&navigation=Voorpagina&language=nl&navigationItemId=20002"
f=urllib2.urlopen(url)

soup = BeautifulSoup(f)
links = []
for link in soup.findAll("a"):    
    linktext = link.get("href")
    if linktext != None:
        if linktext[-3:] == "xml":
            links.append(UnicodeDammit(linktext).unicode_markup)

# %%
# 1.2            
fileNames = []            
for linkUrl in links:
    rssPage = urllib2.urlopen(linkUrl)
    
    # write the files to the Data folder as xml and use the feedname as filename
    fileName = "Data/"
    fileName += linkUrl[25:-4].replace("/", "_")
    fileName += ".xml"

    fileNames.append(fileName)
    
    rssFile = open(fileName, 'w+')
    
    rssFile.writelines(rssPage.readlines())
    rssFile.close()

# %%
# 1.3    
xmlDictList = []
for rssFileName in fileNames:
    
    # open all the files
    rssFile = open(rssFileName, "r")

    # parse the xml
    parsedRss = etree.parse(rssFile)
    
    # get the channel name from the filename
    channel = rssFileName[5:-4]
    
    #get all rss items
    items = parsedRss.xpath('//item')
    
    # make a dict for each rss item, and append to list
    for item in items:
        xmlDict = {}
        xmlDict["title"] = item.find("title").text
        xmlDict["channel"] = channel
        xmlDict["url"] = item.find("link").text
        xmlDict["date"] = item.find("pubDate").text
        xmlDictList.append(xmlDict)

# %%
# 1.4
numberPerChannel = {}

for xmlDict in xmlDictList:
    
    if xmlDict["channel"] in numberPerChannel:
    
        numberPerChannel[xmlDict["channel"]] += 1
        
    else:
        
        numberPerChannel[xmlDict["channel"]] = 1

nonDoubles = []
doubles = 0
for item in items:
    if xmlDict["title"] not in nonDoubles:
        nonDoubles.append(xmlDict["title"])
        
    else:
        doubles += 1
        
    
print "Total number of rss items:", len(xmlDictList)
print numberPerChannel
print "Number of doubles:", doubles
# Out:
# Total number of rss items: 760
# {u'buitenland_rss': 40, u'rss': 40, u'video_opmerkelijk_rss': 40, u'tech-media_rss': 40, u'nieuws_reizen_rss': 40, u'video_binnenland_rss': 40, u'opinie_rss': 40, u'video_buitenland_rss': 40, u'nieuws_opmerkelijk_rss': 40, u'politiek_rss': 40, u'video_rss': 40, u'nieuws_rss': 40, u'nieuws_economie_rss': 40, u'sport_rss': 40, u'nieuws_gezondheidwetenschap_rss': 40, u'video_sport_rss': 40, u'nieuws_binnenland_rss': 40, u'video_cultuur_rss': 40, u'nieuws_cultuur_rss': 40}
# Number of doubles: 39

# %%
#1.5
with open('Data/xmlDictList.csv', 'w+') as csvFile:
    

    writer = UnicodeWriter(csvFile, delimiter =",",  quoting=csv.QUOTE_ALL)
    writer.writerow(['title', 'channel', 'url', 'date'])
    for xmlDict in xmlDictList:

        writer.writerow([xmlDict['title'], xmlDict['channel'], xmlDict['url'], xmlDict['date']])
    
    csvFile.close()

# %% [markdown]
# The google fusion table can be found [here](https://www.google.com/fusiontables/DataSource?docid=1dufhU66wjuY2Ufc3fvQs5mgON9Ysszhm8b8SmfbF).

# %%
# 1.6
articles = []
for dict in xmlDictList:
    url = dict['url']
    date = dict['date']
    html = urllib2.urlopen(url).read()
    soup = BeautifulSoup(html)
    text = soup.get_text()
    print text
    articles.append(text)
# Out:
# Bende breekt records met cyberkraak banken | Media | de Volkskrant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# var _sf_startpt = (new Date()).getTime()
#
#
#     /**
#      Main module, holding everything to make De volkskrant work
#
#      @module App
#      **/
#     var App = {};
#
#     /* GENERAL */
#     var pe_adsLevels = [["media", "20010", "default"]];
#     var pe_navType = 'default';
#     var xfp_posities = [
#
#
#
#             "mid--large--1", "top--large--1", "top--medium--1", "mid--small--1", "top--small--1", "rectangle--large--1", "ligatus--large--1", "ligatus--medium--1", "layer--large--1", "layer--medium--1"
#
#
#
#
#     ];
#     var xfp_ads = {
#         "top" : {
#             "large" : [ [ 970, 250 ], [ 970, 120 ], [ 970, 90 ], [ 728, 90 ] ],
#             "medium" : [ [ 728, 90 ] ],
#             "small" : [ [ 320, 100 ] , [ 320, 50 ] ]
#         },
#         "mid1" : {
#             "large" : [ [ 300 , 600 ] ],
#             "medium" : [ [ 300 , 600] ],
#             "small" : [ [ 320, 250 ], [ 300, 250 ] ]
#         },
#         "mid2" : {
#             "large" : [ [ 300, 250 ] ],
#             "medium" : [ [ 300, 250 ] ],
#             "small" : []
#         },
#         "aankeiler" : {
#             "large" : [ [ 300, 292 ] ],
#             "medium" : [ [ 300, 292 ] ],
#             "small" : [ [ 300, 292 ] ]
#         },
#         "layer" : {
#             "large" : [ [ 640, 480 ] ],
#             "medium" : [ [ 1024, 768 ], [ 640, 480 ] ],
#             "small" : [ [ 320, 480 ] ]
#         },
#         "marketing1" : {
#             "large" : [ [ 352, 140 ] ],
#             "medium" : [ [ 352, 140 ] ],
#             "small" : []
#         },
#         "marketing2" : {
#             "large" : [ [ 300, 250 ] ],
#             "medium" : [ [ 728, 90 ] ],
#             "small" : []
#         },
#         "aanbieding": {
#             "large" : [ [ 299, 138 ] ],
#             "medium" : [ [ 299, 138 ] ],
#             "small" : [ [ 299, 138 ] ]
#         },
#         "rectangle": {
#             "large" : [ [ 300, 250 ] ],
#             "medium" : [ [ 300, 250 ] ],
#             "small" : [ [ 300, 250 ] ]
#         },
#         "ligatus": {
#             "large" : [ [ 600, 250 ] ],
#             "medium" : [ [ 600, 250 ] ],
#             "small" : [ [ 600, 250 ] ]
#         }
#     };
#
#     var ssoUrl="https://caps.volkskrant.nl";
#     var ssoService="/service";
#     var login={'url':'http://www.volkskrant.nl/user/loggedIn.do', 'id':'caps-vk-1201'};
#     var paywall={'url':'http://www.volkskrant.nl/user/paywall.do', 'id':'caps-vk-1202'};
#     var comment={'url':'http://www.volkskrant.nl/user/reaction.do','id':'caps-vk-1203'};
#
#     var userdataUrl="http://www.volkskrant.nl/json/userdata.do";
#     var statisticsUrl = "http://stats.persgroep.nl/statistics.js";
#
#
#
#
#
#     function slotRenderEndedCallback(id, empty, size) {
#         var elm = document.getElementById(id);
#         if(elm){
#             if(empty){
#                 elm.className = elm.className + " js-is-empty";
#             } else {
#                 elm.className = elm.className + " js-is-not-empty";
#                 elm.style.width = size[0] + 'px';
#             }
#         }
#     };
#
#     function hasClass(elm, className) {
#         return elm.className.match(new RegExp('(\\s|^)' + className + '(\\s|$)'));
#     }
#
#     function removeClass(elm, className) {
#         if (hasClass(elm,className)) {
#             var reg = new RegExp('(\\s|^)' + className + '(\\s|$)');
#             elm.className = elm.className.replace(reg, ' ');
#         }
#     }
#
#     function addClass(elm, className) {
#         if (!this.hasClass(elm, className)) elm.className += " " + className;
#     }
#
#     function dimensionChangeCallback(originalDisplay) {
#         var html = document.getElementsByTagName("html")[0],
#             className = "js-no-ads";
#
#         if(originalDisplay){
#             removeClass(html, className);
#         } else {
#             addClass(html, className);
#         }
#     }
#
#     DART.init({
#         'breakpoints': {767: 'small', 1023: 'medium', 1500: 'large'},
#         'onDimensionChange': dimensionChangeCallback,
#         'onSlotRenderEnded': slotRenderEndedCallback
#     });
#
#
#     DART.initializeGoogleAds({
#         'tagPrefix': '/7594/vk/vk.site-' + DART.returnDevice() + '/',
#         'ads': xfp_ads,
#         'positions': xfp_posities,
#         'pageType': 'articleDetail',
#
#         'compId': '3852082',
#
#
#         'nodeIds': [2001,2263,2018,2099,2285,2345,2288],
#
#         'hyperdistribution': false,
#         'levels': pe_adsLevels,
#         'navType': pe_navType
#     });
#
#
#
#
#     var _utsp = {};
#     var _utsc = _utsc || [];
#     _utsp.host = 'http://utsdpn.persgroep.net/';
#     _utsp.sslHost = 'https://utsdpn.persgroep.net/:443';
#     _utsp.vea_mode = 'disable';
#     (function() {
#         var uts = document.createElement('script');
#         uts.type = 'text/javascript';
#         uts.async = true;
#         uts.src = ('https:' == document.location.protocol ? _utsp.sslHost : _utsp.host) + '/uts-static/uts-no-vea.min.js';
#         var s = document.getElementsByTagName('script')[0];
#         s.parentNode.insertBefore(uts, s);
#     })();
#
#
#
#
# dataLayer = [{'ua_navigation' : 'media',
# 'ua_accessType' : 'FREE',
# 'ua_assetAuthor' : 'Michael Persson',
# 'ua_numberOfChars' : '3515',
# 'ua_brandID' : '2001',
# 'ua_pageType' : 'detail',
# 'ua_assetType' : 'DEFAULT ARTICLE',
# 'ua_contentID' : '3852082',
# 'ua_assetPublicationDate' : '1424040420',
# 'ua_navigationID' : '20010'}];
#
#
#
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-KX8PFJ');
#
#
#
#
#
#
#
#
#
#
# 	if ( DART.returnDevice() === "large" ){
#     	DART.showGoogleAd( "top--large--1" );
#     }
#
#
#
#
# 	if ( DART.returnDevice() === "medium" ){
#     	DART.showGoogleAd( "top--medium--1" );
#     }
#
#
#
#
#
# De Volkskrant
#
#
# Media
#
#
#
#
#
#
#
#
# Navigatie
#
# Gratis proberen
#
#
# Nieuws
#
#
#
# Voorpagina
#
#
#
#
#
#
#
#
#
# Egypte zweert wraak na onthoofding 21 koptische christenen door IS
#
#
#
#
# 141
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             141  +
#               +
#               =
#             141
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
# Dader Kopenhagen was 22-jarige Deen
#
#
#
#
# 107
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             107  +
#               +
#               =
#             107
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
# Bende breekt records met cyberkraak banken
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#               +
#               =
#             0
#
#
#
#
# Media
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# De man die de wereld aan de Nutella bracht
#
#
#
#
# 5
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             5  +
#             0  +
#             0  =
#             5
#
#
#
#
#
#
#                             Economie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Waarom is één biertje nooit genoeg?
#
#
#
#
# 55
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             55  +
#             0  +
#             0  =
#             55
#
#
#
#
#
#
#                             Wetenschap
#
#
#
#
#
#
#
#
#
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
# Egypte zweert wraak na onthoofding 21 koptische christenen door IS
#
#
#
#
# 141
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             141  +
#               +
#               =
#             141
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
# Dader Kopenhagen was 22-jarige Deen
#
#
#
#
# 107
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             107  +
#               +
#               =
#             107
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
# Bende breekt records met cyberkraak banken
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#               +
#               =
#             0
#
#
#
#
# Media
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Tot twee keer toe weet dader te ontsnappen in Kopenhagen
#
#
#
#
# 24
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             24  +
#             0  +
#             0  =
#             24
#
#
#
#
#
#
#                             Buitenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Feministische pornomaakster bekritiseert 50 shades
#
#
#
#
# 19
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             19  +
#             0  +
#             0  =
#             19
#
#
#
#
#
#
#                             Leven
#
#
#
#
#
#
#
#
#
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
# Nederlandse trainers in Irak gestart
#
#
#
#
# 19
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             19  +
#               +
#               =
#             19
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
# Nederland geen doelwit wereldwijde bankhack
#
#
#
#
# 3
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             3  +
#               +
#               =
#             3
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
# KNMI waarschuwt voor gladheid in de nacht en morgenochtend
#
#
#
#
# 30
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             30  +
#               +
#               =
#             30
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Kramer onttroont Bergsma met wereldrecord op laaglandbaan
#
#
#
#
# 8
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             8  +
#             0  +
#             0  =
#             8
#
#
#
#
#
#
#                             Binnenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Gaswinning loopt op zijn einde. En iedereen weet het
#
#
#
#
# 78
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             78  +
#             0  +
#             0  =
#             78
#
#
#
#
#
#
#                             Opinie
#
#
#
#
#
#
#
#
#
#
#
#
# Opinie
#
#
#
#
#
#
#
#
#
# Geest van wraakzuchtig revisionisme is uit de fles
#
#
#
#
# 30
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#             20  +
#               =
#             30
#
#
#
#
# Dirk-Jan van Baar
#
#
#
#
#
#
#
#
#
# 'Dekker creëert markt voor ideologen, aasgieren en Jomanda's'
#
#
#
#
# 40
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             25  +
#             15  +
#               =
#             40
#
#
#
#
# Opinie
#
#
#
#
#
#
#
#
#
# Moslima's, wees niet telkens zo snel beledigd
#
#
#
#
# 212
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             146  +
#             66  +
#               =
#             212
#
#
#
#
# Opinie
#
#
#
#
#
#
#
#
#
#
#
#
# Gastcolumn Geerten Waling
#
#
#
#
#
#
#
#
#
# 190
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             168  +
#             22  +
#             0  =
#             190
#
#
#
#
#  COLUMN
#
#
#
#
#
#
#
#
# De Betrouwbare Mannetjes
#
#
# MelleRunderkamp
#
#
#
#
#
# 19
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             19  +
#             0  +
#             0  =
#             19
#
#
#
#
#  COLUMN
#
#
#
#
#
#
#
#
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
# 'Hackers sluisden tientallen miljoenen van banken weg'
#
#
#
#
# 37
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             37  +
#               +
#               =
#             37
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
# Bende breekt records met cyberkraak banken
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#               +
#               =
#             0
#
#
#
#
# Media
#
#
#
#
#
#
#
#
#
# Nederland geen doelwit wereldwijde bankhack
#
#
#
#
# 3
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             3  +
#               +
#               =
#             3
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# De man die de wereld aan de Nutella bracht
#
#
#
#
# 5
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             5  +
#             0  +
#             0  =
#             5
#
#
#
#
#
#
#                             Economie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Van weggegooid eten kun je leuk op vakantie
#
#
#
#
# 20
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             20  +
#             0  +
#             0  =
#             20
#
#
#
#
#
#
#                             Economie
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sport
#
#
#
#
#
#
#
#
#
# Ajax knokt zich in enerverend duel langs FC Twente
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#               +
#               =
#             0
#
#
#
#
# Eredivisie
#
#
#
#
#
#
#
#
#
# Zilver voor debutante Achtereekte, Sablikova pakt goud
#
#
#
#
# 5
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             5  +
#               +
#               =
#             5
#
#
#
#
# Sport
#
#
#
#
#
#
#
#
#
# Inzet Veltman onzeker voor duel met Legia
#
#
#
#
# 3
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             3  +
#               +
#               =
#             3
#
#
#
#
# Sport
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Kramer onttroont Bergsma met wereldrecord op laaglandbaan
#
#
#
#
# 8
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             8  +
#             0  +
#             0  =
#             8
#
#
#
#
#
#
#                             Binnenland
#
#
#
#
#
#
#
#
#
#
# De Twaalfde Man Paul
#
#
# PaulOnkenhout
#
#
#
#
#
# 6
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             5  +
#             1  +
#             0  =
#             6
#
#
#
#
#  COLUMN
#
#
#
#
#
#
#
#
#
#
#
#
# Tech
#
#
#
#
#
#
#
#
#
# Bende breekt records met cyberkraak banken
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#               +
#               =
#             0
#
#
#
#
# Media
#
#
#
#
#
#
#
#
#
# 'Hackers sluisden tientallen miljoenen van banken weg'
#
#
#
#
# 37
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             37  +
#               +
#               =
#             37
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
# Nederland geen doelwit wereldwijde bankhack
#
#
#
#
# 3
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             3  +
#               +
#               =
#             3
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# De Drie Apps van de Week: Limbo, Evoland en Blendle Trending
#
#
#
#
# 6
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             6  +
#             0  +
#             0  =
#             6
#
#
#
#
#
#
#                             Tech
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Game-pc vermomd als spelcomputer
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
#
#                             Tech
#
#
#
#
#
#
#
#
#
#
#
#
#
# Media
#
#
#
#
#
#
#
#
#
# 'NOS mijdt ouderenthema's tijdens verkiezingsdebat'
#
#
#
#
# 12
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             12  +
#               +
#               =
#             12
#
#
#
#
# Politiek
#
#
#
#
#
#
#
#
#
# Bende breekt records met cyberkraak banken
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#               +
#               =
#             0
#
#
#
#
# Media
#
#
#
#
#
#
#
#
#
# 'Nederland op vijfde plek met bijna miljoen Netflix-abonnees'
#
#
#
#
# 31
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             31  +
#               +
#               =
#             31
#
#
#
#
# Media
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Casual Vacancy, Het Groot-Brittannië van..., The Genius of Photography
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#                             Televisie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Groenland, Lincoln, Winter's Bone
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#                             Televisie
#
#
#
#
#
#
#
#
#
#
#
#
# Wetenschap
#
#
#
#
#
#
#
#
#
# VS staan genetisch gemodificeerde appels toe
#
#
#
#
# 14
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             14  +
#               +
#               =
#             14
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
# Schippers over kritiek PvdA-senator: zorgstelsel wel solidair
#
#
#
#
# 24
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             24  +
#               +
#               =
#             24
#
#
#
#
# Zorg
#
#
#
#
#
#
#
#
#
# Gigantische ijsvlakte Antarctica staat op breken
#
#
#
#
# 483
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             483  +
#               +
#               =
#             483
#
#
#
#
# Wetenschap
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Waarom is één biertje nooit genoeg?
#
#
#
#
# 55
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             55  +
#             0  +
#             0  =
#             55
#
#
#
#
#
#
#                             Wetenschap
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# De buizerd is lomp en lui, maar efficiënt
#
#
#
#
# 4
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             4  +
#             0  +
#             0  =
#             4
#
#
#
#
#
#
#                             Wetenschap
#
#
#
#
#
#
#
#
#
#
#
#
#
# Politiek
#
#
#
#
#
#
#
#
#
# Zijlstra: kans op meer gaswinning heel klein
#
#
#
#
# 19
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             19  +
#               +
#               =
#             19
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
# 'NOS mijdt ouderenthema's tijdens verkiezingsdebat'
#
#
#
#
# 12
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             12  +
#               +
#               =
#             12
#
#
#
#
# Politiek
#
#
#
#
#
#
#
#
#
# Veertig landen bijeen op conferentie VN-vredesmissies in Amsterdam
#
#
#
#
# 1
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             1  +
#               +
#               =
#             1
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Binnenhof staat voor 'grootste volksverhuizing ooit'
#
#
#
#
# 6
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             6  +
#             0  +
#             0  =
#             6
#
#
#
#
#
#
#                             Binnenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# De echte strijd om het gas komt nog
#
#
#
#
# 14
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             14  +
#             0  +
#             0  =
#             14
#
#
#
#
#
#
#                             Binnenland
#
#
#
#
#
#
#
#
#
#
#
#
#
# Specials
#
#
# Cartoons
#
#
# Foto
#
#
# Vonk
#
#
# Dag In Dag uit
#
#
#
#
#
# Cultuur &
#                 Leven
#
#
#
# Voorpagina
#
#
#
#
#
#
#
#
#
# Bioscopen beleven beste Valentijnsdag ooit
#
#
#
#
# 23
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             23  +
#               +
#               =
#             23
#
#
#
#
# Film
#
#
#
#
#
#
#
#
#
# Faithless kondigt reünie aan
#
#
#
#
# 133
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             133  +
#               +
#               =
#             133
#
#
#
#
# Muziek
#
#
#
#
#
#
#
#
#
# Nederlandse korte animatiefilm genomineerd voor Oscar
#
#
#
#
# 35
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             35  +
#               +
#               =
#             35
#
#
#
#
# Oscars
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fotograaf Erwin Olaf: 'Ik heb lang genoeg het majorettekorps aangevoerd'
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#             0  +
#             0  =
#             10
#
#
#
#
#
#
#                             Leven
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Niets-aan-de-handkunst uit een foute periode
#
#
#
#
# 4
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             4  +
#             0  +
#             0  =
#             4
#
#
#
#
#
#
#                             Beeldende Kunst
#
#
#
#
#
#
#
#
#
#
#
#
#
# Agenda
#
#
# Recensies
#
#
#
#
#
#
#
#
#
# Vrolijkmakende popliedjes in jarenvijftigsfeer
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#               +
#               =
#             0
#
#
#
#
# Muziek
#
#
#
#
#
#
#
#
#
# Kunstmusea opnieuw de les gelezen met advertentie
#
#
#
#
# 5
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#               +
#             3  =
#             5
#
#
#
#
# musea en galerieën
#
#
#
#
#
#
#
#
#
# 'Troostmeisjes' van Nederlandse fotograaf Banning nu ook te zien in Japan
#
#
#
#
# 7
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             3  +
#               +
#             4  =
#             7
#
#
#
#
# Agenda
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	                De condition humaine is een...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Edward O. Wilson
# The meaning of human existence
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
# 	                        Non-fictie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Huiveringwekkend bankiersportret
# Vol humor en zelfreflectie...
#
#
#
#
# 174
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             174  +
#             0  +
#             0  =
#             174
#
#
#
#
#
# Boeken
#
#
#
#
#
#
#
#
#
#
#
# Film
#
#
#
#
#
#
#
#
#
# Nederlandse korte animatiefilm genomineerd voor Oscar
#
#
#
#
# 35
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             35  +
#               +
#               =
#             35
#
#
#
#
# Oscars
#
#
#
#
#
#
#
#
#
# Bioscopen beleven beste Valentijnsdag ooit
#
#
#
#
# 23
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             23  +
#               +
#               =
#             23
#
#
#
#
# Film
#
#
#
#
#
#
#
#
#
# Zuid-Amerika favoriet in Berlijn
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#               +
#               =
#             2
#
#
#
#
# Film
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# De film die 'Fifty shades' preuts maakt
#
#
#
#
# 5
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             5  +
#             0  +
#             0  =
#             5
#
#
#
#
#
#
#                             Film
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Forbidden Zone
#
#
#
#
#                             Theater
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Muziek
#
#
#
#
#
#
#
#
#
# Visage-zanger Steve Strange (55) overleden
#
#
#
#
# 9
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             9  +
#               +
#               =
#             9
#
#
#
#
# Muziek
#
#
#
#
#
#
#
#
#
# Paradiso begint eigen platenlabel
#
#
#
#
# 113
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             113  +
#               +
#               =
#             113
#
#
#
#
# Muziek
#
#
#
#
#
#
#
#
#
# Faithless komt na vier jaar alweer samen
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#               +
#               =
#             10
#
#
#
#
# Muziek
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# De beste muziek van de week (7): Father John Misty, Herman Brock Jr. en Gretchen Peters
#
#
#
#
# 4
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             4  +
#             0  +
#             0  =
#             4
#
#
#
#
#
#
#                             Muziek
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Paloma Faith een bitch? Nee, een heerlijke meid
#
#
#
#
# 15
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             15  +
#             0  +
#             0  =
#             15
#
#
#
#
#
#
#                             Muziek
#
#
#
#
#
#
#
#
#
#
#
#
# Reizen
#
#
#
#
#
#
#
#
#
# Snelweg van Lille naar Parijs weer open
#
#
#
#
# 30
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             30  +
#               +
#               =
#             30
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
# Eerste verre bestemming Eindhoven Airport
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#               +
#               =
#             10
#
#
#
#
# Reizen
#
#
#
#
#
#
#
#
#
# Weer toeriste verkracht in India, politie zoekt verdachte 'gids'
#
#
#
#
# 11
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             11  +
#               +
#               =
#             11
#
#
#
#
# Reizen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Buitenzwemmen onder alle omstandigheden
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#                             Reizen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Coolest Cooler: de succesvolste Kickstartercampagne ooit
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#                             Reizen
#
#
#
#
#
#
#
#
#
#
#
#
# Koken & Eten
#
#
#
#
#
#
#
#
#
# Antibioticaresistente bacteriën op helft van vis en garnalen
#
#
#
#
# 1
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#               +
#             1  =
#             1
#
#
#
#
# Koken & Eten
#
#
#
#
#
#
#
#
#
# VS staan genetisch gemodificeerde appels toe
#
#
#
#
# 14
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             14  +
#               +
#               =
#             14
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
# Vitamines geven chemieconcern DSM hoofdpijn
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#               +
#               =
#             0
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 'Bier en psychiatrie, dat gaat toch niet samen?'
#
#
#
#
# 19
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             19  +
#             0  +
#             0  =
#             19
#
#
#
#
#
#
#                             Koken & Eten
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Piekfijne Les Hautes Sentes van de Hema
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
#
#                             Koken & Eten
#
#
#
#
#
#
#
#
#
#
#
#
#
# Theater
#
#
#
#
#
#
#
#
#
# Victor Löw en Halina Reijn genomineerd voor belangrijkste toneelprijzen
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#               +
#               =
#             10
#
#
#
#
# Theater
#
#
#
#
#
#
#
#
#
# Films van 'legendarische' theatervoorstellingen in digitale filmbank
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#               +
#               =
#             10
#
#
#
#
# Theater
#
#
#
#
#
#
#
#
#
# Geen 'Konzertsaal' in München
#
#
#
#
# 1
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             1  +
#               +
#               =
#             1
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fotograaf Erwin Olaf: 'Ik heb lang genoeg het majorettekorps aangevoerd'
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#             0  +
#             0  =
#             10
#
#
#
#
#
#
#                             Leven
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Chuck en Charlene
#
#
#
#
#                             Jeugd
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Boeken
#
#
#
#
#
#
#
#
#
# Israëlische schrijvers woedend over bemoeienis Netanyahu met Israël Prijs
#
#
#
#
# 27
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             27  +
#               +
#               =
#             27
#
#
#
#
# Israëlisch-Palestijns conflict
#
#
#
#
#
#
#
#
#
# De Avonden van Gerard Reve krijgt Engelse vertaling
#
#
#
#
# 26
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             26  +
#               +
#               =
#             26
#
#
#
#
# Boeken
#
#
#
#
#
#
#
#
#
# Hannelore Grünberg-Klein (87), moeder Arnon Grunberg, overleden
#
#
#
#
# 76
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             76  +
#               +
#               =
#             76
#
#
#
#
# Boeken
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fotograaf Erwin Olaf: 'Ik heb lang genoeg het majorettekorps aangevoerd'
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#             0  +
#             0  =
#             10
#
#
#
#
#
#
#                             Leven
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	                De condition humaine is een...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Edward O. Wilson
# The meaning of human existence
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
# 	                        Non-fictie
#
#
#
#
#
#
#
#
#
#
#
# Beeldende Kunst
#
#
#
#
#
#
#
#
#
# Schotse kunst ging kelder in
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#               +
#               =
#             0
#
#
#
#
# musea en galerieën
#
#
#
#
#
#
#
#
#
# 'World Press Photo wordt denktank'
#
#
#
#
# 14
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             14  +
#               +
#               =
#             14
#
#
#
#
# Tech
#
#
#
#
#
#
#
#
#
# Elektricien Picasso voor heling voor rechter
#
#
#
#
# 12
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             12  +
#               +
#               =
#             12
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fotograaf Erwin Olaf: 'Ik heb lang genoeg het majorettekorps aangevoerd'
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#             0  +
#             0  =
#             10
#
#
#
#
#
#
#                             Leven
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Niets-aan-de-handkunst uit een foute periode
#
#
#
#
# 4
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             4  +
#             0  +
#             0  =
#             4
#
#
#
#
#
#
#                             Beeldende Kunst
#
#
#
#
#
#
#
#
#
#
#
#
#
# Leven
#
#
# Mode & Mooi
#
#
# Festivals
#
#
# Televisie
#
#
# Voordeel
#
#
#
#
#
#
#
#
#
# Gebruikersnavigatie
#
#
#
# Gebruikersnavigatie
#
#
#
#   Zoeken
#
#
#
#
#
#
# Zoeken
#
#
#
#
#
#
#
#
#
#
#  Mijn nieuws
#  Ik volg
#  Lees later
#
#
#
#
#                             Uitloggen
#
#
#
#                             Account
#
#
#
#
#
#                             Account
#
#
#
#                             Uitloggen
#
#
#
#
#
#
#
#
#
#
#
# Mijn nieuws
#
#
#
#
#  Ik volg
#
#
#
#
#  Lees later
#
#
#
#
#  Uitloggen
#
#
#                         Account
#
#
#
#
#
#  Inloggen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Weer
#
#
#
#
#
# Beurs
#
#
# Banen
#
#
#
#
#
#
# Abonneer
# Digitale krant
# Service
# Winkel
# Voordeel
#
#
#
#
#
#
#
#
#
#
#
#
# Media
#
#
#
#
#
#
#
#
#
# Deel
#
#
# Deel dit artikel via
#
#
#
#
#
#
#
# 0
#
#
#                                             Twitter
#
#
#
#
#
#
#
#
#
# 0
#
#
#                                             Facebook
#
#
#
#
#
#
#
#
#
# 0
#
#
#                                             Linkedin
#
#
#
#
#
#
#
#
#
# 0
#
#
#                                             Google +
#
#
#
#
#
#
#
#
#
# 0
#
#
#                                             E-mail
#
#
#
#
#
#
# 0
#
#
#
#
#
#
#
#
# Bewaar
#
#
#
#
# 0
#
#
#
#
#
# Bewaar
#
#
#
# 0
#
#
#
#
#
# Bewaar
#
#
#
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	if ( DART.returnDevice() === "small" ){
#     	DART.showGoogleAd( "top--small--1" );
#     }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# © ANP
#
#
#
#
# Bende breekt records met cyberkraak banken
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     Een internationale cyberbende heeft een van de grootste bankovervallen aller tijden gepleegd. Door honderd banken verspreid over de wereld te hacken hebben ze de afgelopen twee jaar tussen 300 miljoen en één miljard dollar buitgemaakt.
#
#
#
#
#
# Door: Michael Persson
#
# 15 februari 2015, 23:47
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
#
#
#
#
#
#
# Analisten van het Russische computerbeveiligingsbedrijf Kaspersky, dat het nieuws dit weekend naar buiten bracht, noemen het 'een bijzonder uitgekiende en professionele cyberbankroof'. Een woordvoerder van het Team High Tech Crime van de Nederlandse politie bevestigt de wereldwijde digitale overval. 'Dit is een heel brede operatie geweest.'Tot dusver richtten op geld beluste computercriminelen zich meestal op individuele rekeninghouders, meestal door zich met nepmailtjes of nepwebsites als de bank voor te doen. In dit geval kozen de hackers de kortste weg naar het grote geld, door de banken zelf te infiltreren.
#
#
#
#
#
#
#
# Ingenieus
#
#
#
#
#
# Als de banken de softwarefouten in Microsoft Office en Word gerepareerd hadden, was er niets gebeurd
#
#
#
#
# In tegenstelling tot wat The New York Times zaterdag berichtte, lijken Nederlandse banken geen slachtoffer te zijn geweest, zegt Jornt van der Wiel van Kaspersky, die nauw betrokken was bij het onderzoek naar de hack. Ook de Nederlandse Vereniging van Banken (NVB) en de politie zeggen dat Nederlandse banken niet geraakt zijn. De meeste banken hebben de afgelopen weken wel intern onderzoek laten doen, nadat zij waren ingelicht over de hack. In dertig andere landen zijn wel miljoenen weggesluisd door de Carbanak-bende, vernoemd naar de kwaadaardige software die de hackers gebruikten. Kaspersky noemt Rusland, de Verenigde Staten, Duitsland, China en Oekraïne als belangrijkste doelwitten. Per bank werd maximaal 10 miljoen dollar weggehaald. 'Dat is het maximale bedrag dat een bank van de verzekering terugkrijgt', zegt Van der Wiel. 'Daarmee hebben de hackers het per bank relatief klein gehouden, om niet te veel alarmbellen te laten afgaan.' De hackers gingen ingenieus te werk. Eerst stuurden ze een mailtje met een virus naar personeelsleden van de bank. Als een daarvan werd geopend, waren de hackers binnen. Overigens maakten ze daarbij gebruik van al enige tijd bekende softwarefouten in Microsoft Office en Word. 'Als de banken die gerepareerd hadden, was er niets gebeurd', zegt Van der Wiel. Eenmaal binnen probeerden de hackers bij een systeembeheerder te komen en diens wachtwoord te achterhalen. Daarna hadden ze toegang tot grote delen van het netwerk.
#
#
#
#
#
#
#
# Methoden
#
#
# Vervolgens bestudeerden de cybercriminelen de werkwijze van de bank gedurende twee tot vier maanden. Met zogeheten RAT's, remote access tools, keken ze mee op de geïnfecteerde computers en achterhaalden ze de toetsaanslagen (en dus de wachtwoorden) van belangrijke medewerkers. Ook kregen ze controle over camera's op de computers van de medewerkers, waardoor ze de praktische gang van zaken bij de betreffende bank haarfijn in kaart konden brengen. Het cashen gebeurde op verschillende manieren. Het begon met het hacken van geldautomaten: zo stapte in Kiev, in een nacht in 2013, om 2.59 uur een man met een zwarte tas een halletje met pinautomaten binnen, die een minuut later spontaan biljetten begonnen uit te spuwen. Een andere methode was puur administratief: de hackers zetten even 10.000 euro op een rekening waar eigenlijk maar 1.000 euro op stond, en boekten vervolgens 9.000 euro over naar een bank in het buitenland. Kaspersky kreeg de hackers in mei 2014 in het vizier. Het lijkt een Russisch-Oekraïense bende te zijn, met enkele leden in China.Waarschijnlijk is de bende niet door een land aangestuurd.
#
#
#
#
#
#
#
#
#
#
#
#
# Volg en lees meer over:
#
#
#
#
#  Tech
#
#
#
#
#
#  Tech
#
#
#
#
#  Internet & Multimedia
#
#
#
#
#
#  Internet & Multimedia
#
#
#
#
#  Buitenland
#
#
#
#
#
#  Buitenland
#
#
#
#
#  Economie
#
#
#
#
#
#  Economie
#
#
#
#
#  Internetcriminaliteit
#
#
#
#
#
#  Internetcriminaliteit
#
#
#
#
#  Media
#
#
#
#
#
#  Media
#
#
#
#
#  Internet
#
#
#
#
#
#  Internet
#
#
#
#
#
#
#
#
#
#
#
#
#
#   Volgen
#
#
#
#   Volgen
#
#
#
# Michael Persson
#
#
#
#
#  Twitter
#
#  E-mail
#
#
# 				Meer Michael Persson
#
#
#
#
#
#
#
#
# 		DART.showGoogleAd( "ligatus--medium--1" );
#
#
#
#
# 		DART.showGoogleAd( "ligatus--large--1" );
#
#
#
#
#
#
#
#
# Sidebar
#
#
#
#
#
#
#
#
#
#
#
#                     Gerelateerde artikelen
#
#
#
#
#
#
#
#
#
#
# Nederland geen doelwit wereldwijde bankhack
#
#
#
# 15 feb 2015
#
#
#
#
#
#
#
#
#
# 'Hackers sluisden tientallen miljoenen van banken weg'
#
#
#
# 15 feb 2015
#
#
#
#
#
#
#
#
#
# Air France-KLM ontkent 'sloop' KLM
#
#
#
# 15 feb 2015
#
#
#
#
#
#
#
#
#
#
#
# 	if ( DART.returnDevice() === "large" ){
#     	DART.showGoogleAd( "mid--large--1" );
#     }
#
#
#
#
#
# Meest gelezen Media
#
#
#
#
#
# 1
#  15171
#
#
#
#
#
# Nieuwslezer wankelt, Amerika siddert
#
#
#
#
# Media
#
#
#
#
#
#
#
#
# 2
#  14064
#
#
#
#
#
# Better Call Saul: veel kijkers en goede kritieken
#
#
#
# Media
#
#
#
#
#
#
#
#
# 3
#  13806
#
#
#
#
#
# Wie is de Mol-recap: Rik is geen mol. Hooguit een laffe
#
#
#
# Recap: Wie is de mol?
#
#
#
#
#
#
#
#
# 4
#  10458
#
#
#
#
#
# NOS zendt beelden Tarik Z. niet meer uit
#
#
#
# Gewapende man bij NOS
#
#
#
#
#
#
#
#
# 5
#  9918
#
#
#
#
#
# Nieuwslezer Brian Williams 'maakte fout niet opzettelijk'
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
#  Bekijk hele lijst
#
#
#
#
#
# 		if ( DART.returnDevice() === "large" ){
# 			DART.showGoogleAd( "rectangle--large--1" );
# 		}
#
#
#
#
#
#
#
#
#
#
#
# 	if ( DART.returnDevice() === "small" ){
#     	DART.showGoogleAd( "mid--small--1" );
#     }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Verder in Nieuws
#
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
# Tot twee keer toe weet dader te ontsnappen in Kopenhagen
#
#
#
#
# 24
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             24  +
#             0  +
#             0  =
#             24
#
#
#
#
#
#
#                             Buitenland
#
#
#
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
# Kramer onttroont Bergsma met wereldrecord op laaglandbaan
#
#
#
#
# 8
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             8  +
#             0  +
#             0  =
#             8
#
#
#
#
#
#
#                             Binnenland
#
#
#
#
#
#
#
#
# Opinie
#
#
# Stekel
#
#
# Sandervan Walsum
#
#
#
#
#
# 4
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             3  +
#             1  +
#             0  =
#             4
#
#
#
#
#  COLUMN
#
#
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
# De man die de wereld aan de Nutella bracht
#
#
#
#
# 7
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             7  +
#             0  +
#             0  =
#             7
#
#
#
#
#
#
#                             Economie
#
#
#
#
#
#
#
#
# Sport
#
#
#
#
#
#
#
#
#
# Max Verstappen is geboren om te racen
#
#
#
#
# 17
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             17  +
#             0  +
#             0  =
#             17
#
#
#
#
#
#
#                             Sport
#
#
#
#
#
#
#
#
# Tech
#
#
#
#
#
#
#
#
#
# De Drie Apps van de Week: Limbo, Evoland en Blendle Trending
#
#
#
#
# 6
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             6  +
#             0  +
#             0  =
#             6
#
#
#
#
#
#
#                             Tech
#
#
#
#
#
#
#
# Media
#
#
#
#
#
#
#
#
#
# Als ik wil twitteren denk ik: Oude trut, bemoei je er niet mee
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#             0  +
#             0  =
#             10
#
#
#
#
#
#
#                             Media
#
#
#
#
#
#
#
#
# Wetenschap
#
#
#
#
#
#
#
#
#
# Pompgemak
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#                             Wetenschap
#
#
#
#
#
#
#
#
# Politiek
#
#
#
#
#
#
#
#
#
# #binnenskamers: kabinet stuurt nieuws MH17 retour
#
#
#
#
# 102
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             102  +
#             0  +
#             0  =
#             102
#
#
#
#
#
#
#                             Politiek
#
#
#
#
#
#
#
# Vonk
#
#
#
#
#
#
#
#
#
# Met bevende handen veegde ik mijn tranen weg
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
#
#                             Vonk
#
#
#
#
#
#
#
# Televisie
#
#
#
# Logeren
#
# Voor Chantal moet Expeditie Robinson een eitje zijn
#
#
#
# AafBrandt Corstius
#
#
#
#
# 1
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             1  =
#             1
#
#
#
#
#  COLUMN
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Verder in Cultuur & Leven
#
#
#
#
#
# Recensies
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Karen Dawisha beschrijft corrupt regime van Poetin verbluffend nauwkeurig
# Inktzwart beeld van Poetins...
#
#
#
#
# 13
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             12  +
#             1  +
#             0  =
#             13
#
#
#
#
#
# Recensies
#
#
#
#
#
#
# Film
#
#
#
#
#
#
#
#
#
# De film die 'Fifty shades' preuts maakt
#
#
#
#
# 5
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             5  +
#             0  +
#             0  =
#             5
#
#
#
#
#
#
#                             Film
#
#
#
#
#
#
#
#
# Muziek
#
#
#
#
#
#
#
#
#
# Paloma Faith een bitch? Nee, een heerlijke meid
#
#
#
#
# 15
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             15  +
#             0  +
#             0  =
#             15
#
#
#
#
#
#
#                             Muziek
#
#
#
#
#
#
#
# Reizen
#
#
#
#
#
#
#
#
#
# Buitenzwemmen onder alle omstandigheden
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#                             Reizen
#
#
#
#
#
#
#
#
# Koken & Eten
#
#
#
#
#
#
#
#
#
# 'Bier en psychiatrie, dat gaat toch niet samen?'
#
#
#
#
# 19
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             19  +
#             0  +
#             0  =
#             19
#
#
#
#
#
#
#                             Koken & Eten
#
#
#
#
#
#
#
#
# Theater
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Forbidden Zone
#
#
#
#
#                             Theater
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#
#
#
#
# Boeken
#
#
#
#
#
# 	                De condition humaine is een...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Edward O. Wilson
# The meaning of human existence
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
# 	                        Non-fictie
#
#
#
#
#
#
# Beeldende Kunst
#
#
#
#
#
#
#
#
#
# Niets-aan-de-handkunst uit een foute periode
#
#
#
#
# 4
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             4  +
#             0  +
#             0  =
#             4
#
#
#
#
#
#
#                             Beeldende Kunst
#
#
#
#
#
#
#
#
# Leven
#
#
#
#
#
#
#
#
#
# Feministische pornomaakster bekritiseert 50 shades
#
#
#
#
# 19
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             19  +
#             0  +
#             0  =
#             19
#
#
#
#
#
#
#                             Leven
#
#
#
#
#
#
#
#
# Mode & Mooi
#
#
#
#
#
#
#
#
#
# In de winkel
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
#
#                             Mode & Mooi
#
#
#
#
#
#
#
#
# Festivals
#
#
#
#
#
#
#
#
#
# Gast van de Volkskrant Job de Wit: 'De programmeur van Le Guess Who? snapt het
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
#
#                             Festivals
#
#
#
#
#
#
#
# Televisie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Black Sails Seizoen 1
# Dvd-tip
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
# Televisie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Nieuws
#
#
# Media
#
#
# Bende breekt records met cyberkraak banken
#
#
#
#
#
#
#
#
#
# Nu bij de Volkskrant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Naar de winkel
#
#
#
#
#
#
#
#
#
#
#
#
# Twitter
#
#
#
#
#
# Facebook
#
#
#
#
#
# Google+
#
#
#
#
#
#
# Volg de Volkskrant
#
#
# Schrijf u in voor de dagelijkse nieuwsbrief
#
#
#
#
#
#
# Aanvragen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Archief
#
#
#
#
#
# Digitale krant
#
#
#
#
#
# Journalisten Columnisten
#
#
#
#
#
#
# Apps
#
#
# de Volkskrant
#
#
# de Volkskrant Original
#
#
# de Volkskrant Select
#
#
# Overzicht alle apps
#
#
#
#
#
#
#
# de Volkskrant
#
# Over de Volkskrant
# Auteursrecht & Privacy
# Vacatures
# Over deze website
# RSS feeds
#
#
#
#
#
# Service en contact
#
# Abonneren
# Service
# Veelgestelde vragen
# Contactgegevens
# Adverteren
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                         © 2015 - Alle rechten voorbehouden
# Lees de gebruiksvoorwaarden
#
#
#
#
#
#
#
#
#
#
# Nieuws
#
#
# Cultuur & Leven
#
#
#
#
#
#
#
#
#
#
#
#
#
# Weer
#
#
#
#
#
# Beurs
#
#
#
#
#
# Voorpagina
#
#
# Buitenland
#
#
# Binnenland
#
#
# Opinie
#
#
# Economie
#
#
# Sport
#
#
# Tech
#
#
# Media
#
#
# Wetenschap
#
#
# Politiek
#
#
# Specials
#
#
# Cartoons
#
#
# Foto
#
#
# Vonk
#
#
# Dag In Dag uit
#
#
# Abonnement
#
#
# Winkel
#
#
# Service
#
#
#
#
#
#
#
#
#
#
#
#
#
# Voorpagina
#
#
# Agenda
#
#
# Recensies
#
#
# Film
#
#
# Muziek
#
#
# Reizen
#
#
# Koken & Eten
#
#
# Theater
#
#
# Boeken
#
#
# Beeldende Kunst
#
#
# Leven
#
#
# Mode & Mooi
#
#
# Festivals
#
#
# Televisie
#
#
# Voordeel
#
#
# Abonnement
#
#
# Winkel
#
#
# Service
#
#
#
#
#
#
#
# Mijn Volkskrant
#
#
#
#
#  Mijn nieuws
#  Ik volg
#  Lees later
#  Account
#  Uitloggen
#   Inloggen
#
#
# Mijn nieuws
#
#
#
#
#  Ik volg
#
#
#
#
#  Lees later
#
#
#
#                 Account
#
#
#  Uitloggen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ©
#
# Tweets by @
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="//platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#
#
#
#
#
#
# 1
#
#
#
#
#
# Previous
# Next
#
#
#
#
#
#
#
#
#
# De Volkskrant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Deel dit
#
#
#
#
#
#
#
#
#
#
#                             Twitter
#
#
#
#
#
#
#
#
#
#
#
#
#                             Facebook
#
#
#
#
#
#
#
#
#
#
#
#
#                             Linkedin
#
#
#
#
#
#
#
#
#
#
#
#
#                             Google +
#
#
#
#
#
#
#
#
#
#
#
#
#                             E-mail
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# |
#
#
#
#
#
#
#
#
#
#
#
#
# U kunt deze maand nog 5/10 gedeelde VK-plus artikelen gratis lezen.
# Probeer VK-plus 2 weken gratis,zonder verplichtingen
#
#
# Gratis proberen
#
#
#
#                                     Al een account? Log in
#
#
#
# De Volkskrant biedt gratis en betaalde artikelen aan. Betaalde artikelen herkent u aan een VKplus label. Elke maand mag u gratis 10 VKplus artikelen lezen die uw vrienden met u delen.
#
#
#
#
#
# Alles van de Volkskrant
# Complete cultuuragenda
# Stel uw Volkskrant samen
# Deel favoriete artikelen
# De mooiste fotografie
#
#  Lees meer over VKplus?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# U heeft deze maand 5/10 gedeelde VK-plus artikelen gratis gelezen.
#
#
#
#
#
#
#
#
#
#
#
# Cookies op de Volkskrant
#
# Door gebruik te maken van deze website, of door op 'Akkoord' te klikken, geeft u toestemming voor het gebruik van cookies.
# De Volkskrant maakt gebruik van cookies, onder andere om de website te analyseren, het gebruiksgemak te vergroten en advertenties te tonen. Door gebruik te maken van deze website, of door op 'Akkoord' te klikken, geeft u toestemming voor het gebruik van cookies. Wilt u meer informatie over cookies en hoe ze worden gebruikt, bekijk dan ons cookiebeleid.
#
#
#
#
#
#  Akkoord
#
# Meer informatie
#
#
#
#
#
#
#
#
#
#
#         var _sf_async_config={};
#         /** CONFIGURATION START **/
#         _sf_async_config.uid = 46966;
# 	       _sf_async_config.domain = 'volkskrant.nl';
#         _sf_async_config.useCanonical = true;
#         _sf_async_config.sections = 'media'; //CHANGE THIS
#         _sf_async_config.authors = 'Michael Persson';
#         /** CONFIGURATION END **/
#         (function(){
#             function loadChartbeat() {
#                 window._sf_endpt=(new Date()).getTime();
#                 var e = document.createElement('script');
#                 e.setAttribute('language', 'javascript');
#                 e.setAttribute('type', 'text/javascript');
#                 e.setAttribute('src', '//static.chartbeat.com/js/chartbeat.js');
#                 document.body.appendChild(e);
#                 }
#                 var oldonload = window.onload;
#                 window.onload = (typeof window.onload != 'function') ?
#                 loadChartbeat : function()
#                 { oldonload(); loadChartbeat(); }
#                 ;
#         })();
#
#
#
#
#
#
# 	if ( DART.returnDevice() === "large" ){
#     	DART.showGoogleAd( "layer--large--1" );
#     }
#
#
#
#
# 	if ( DART.returnDevice() === "medium" ){
#     	DART.showGoogleAd( "layer--medium--1" );
#     }
#
#
#
#
#
#
#
#
#
#
#
#
# Grange pakt slalomgoud na uitglijder favoriet Hirscher | Sport | de Volkskrant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# var _sf_startpt = (new Date()).getTime()
#
#
#     /**
#      Main module, holding everything to make De volkskrant work
#
#      @module App
#      **/
#     var App = {};
#
#     /* GENERAL */
#     var pe_adsLevels = [["sport", "20008", "default"]];
#     var pe_navType = 'default';
#     var xfp_posities = [
#
#
#
#             "mid--large--1", "top--large--1", "top--medium--1", "mid--small--1", "top--small--1", "rectangle--large--1", "ligatus--large--1", "ligatus--medium--1", "layer--large--1", "layer--medium--1"
#
#
#
#
#     ];
#     var xfp_ads = {
#         "top" : {
#             "large" : [ [ 970, 250 ], [ 970, 120 ], [ 970, 90 ], [ 728, 90 ] ],
#             "medium" : [ [ 728, 90 ] ],
#             "small" : [ [ 320, 100 ] , [ 320, 50 ] ]
#         },
#         "mid1" : {
#             "large" : [ [ 300 , 600 ] ],
#             "medium" : [ [ 300 , 600] ],
#             "small" : [ [ 320, 250 ], [ 300, 250 ] ]
#         },
#         "mid2" : {
#             "large" : [ [ 300, 250 ] ],
#             "medium" : [ [ 300, 250 ] ],
#             "small" : []
#         },
#         "aankeiler" : {
#             "large" : [ [ 300, 292 ] ],
#             "medium" : [ [ 300, 292 ] ],
#             "small" : [ [ 300, 292 ] ]
#         },
#         "layer" : {
#             "large" : [ [ 640, 480 ] ],
#             "medium" : [ [ 1024, 768 ], [ 640, 480 ] ],
#             "small" : [ [ 320, 480 ] ]
#         },
#         "marketing1" : {
#             "large" : [ [ 352, 140 ] ],
#             "medium" : [ [ 352, 140 ] ],
#             "small" : []
#         },
#         "marketing2" : {
#             "large" : [ [ 300, 250 ] ],
#             "medium" : [ [ 728, 90 ] ],
#             "small" : []
#         },
#         "aanbieding": {
#             "large" : [ [ 299, 138 ] ],
#             "medium" : [ [ 299, 138 ] ],
#             "small" : [ [ 299, 138 ] ]
#         },
#         "rectangle": {
#             "large" : [ [ 300, 250 ] ],
#             "medium" : [ [ 300, 250 ] ],
#             "small" : [ [ 300, 250 ] ]
#         },
#         "ligatus": {
#             "large" : [ [ 600, 250 ] ],
#             "medium" : [ [ 600, 250 ] ],
#             "small" : [ [ 600, 250 ] ]
#         }
#     };
#
#     var ssoUrl="https://caps.volkskrant.nl";
#     var ssoService="/service";
#     var login={'url':'http://www.volkskrant.nl/user/loggedIn.do', 'id':'caps-vk-1201'};
# ...
#               =
#             0
#
#
#
#
# musea en galerieën
#
#
#
#
#
#
#
#
#
# 'World Press Photo wordt denktank'
#
#
#
#
# 14
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             14  +
#               +
#               =
#             14
#
#
#
#
# Tech
#
#
#
#
#
#
#
#
#
# Elektricien Picasso voor heling voor rechter
#
#
#
#
# 12
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             12  +
#               +
#               =
#             12
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fotograaf Erwin Olaf: 'Ik heb lang genoeg het majorettekorps aangevoerd'
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#             0  +
#             0  =
#             10
#
#
#
#
#
#
#                             Leven
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Niets-aan-de-handkunst uit een foute periode
#
#
#
#
# 4
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             4  +
#             0  +
#             0  =
#             4
#
#
#
#
#
#
#                             Beeldende Kunst
#
#
#
#
#
#
#
#
#
#
#
#
#
# Leven
#
#
# Mode & Mooi
#
#
# Festivals
#
#
# Televisie
#
#
# Voordeel
#
#
#
#
#
#
#
#
#
# Gebruikersnavigatie
#
#
#
# Gebruikersnavigatie
#
#
#
#   Zoeken
#
#
#
#
#
#
# Zoeken
#
#
#
#
#
#
#
#
#
#
#  Mijn nieuws
#  Ik volg
#  Lees later
#
#
#
#
#                             Uitloggen
#
#
#
#                             Account
#
#
#
#
#
#                             Account
#
#
#
#                             Uitloggen
#
#
#
#
#
#
#
#
#
#
#
# Mijn nieuws
#
#
#
#
#  Ik volg
#
#
#
#
#  Lees later
#
#
#
#
#  Uitloggen
#
#
#                         Account
#
#
#
#
#
#  Inloggen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Weer
#
#
#
#
#
# Beurs
#
#
# Banen
#
#
#
#
#
#
# Abonneer
# Digitale krant
# Service
# Winkel
# Voordeel
#
#
#
#
#
#
#
#
#
#
#
#
# Sport
#
#
#
#
#
#
#
#
#
# Deel
#
#
# Deel dit artikel via
#
#
#
#
#
#
#
# 2
#
#
#                                             Twitter
#
#
#
#
#
#
#
#
#
# 1
#
#
#                                             Facebook
#
#
#
#
#
#
#
#
#
# 0
#
#
#                                             Linkedin
#
#
#
#
#
#
#
#
#
# 0
#
#
#                                             Google +
#
#
#
#
#
#
#
#
#
# 0
#
#
#                                             E-mail
#
#
#
#
#
#
# 3
#
#
#
#
#
#
#
#
# Bewaar
#
#
#
#
# 0
#
#
#
#
#
# Bewaar
#
#
#
# 0
#
#
#
#
#
# Bewaar
#
#
#
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	if ( DART.returnDevice() === "small" ){
#     	DART.showGoogleAd( "top--small--1" );
#     }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# © ANP
#
#
#
#
# Heemskerk blijft Kromowidjojo voor in Amiens
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     Femke Heemskerk heeft vandaag op het internationale zwemgala in het Franse Amiens overtuigend de finale van de 100 meter vrije slag gewonnen. Met een tijd van 53,63 bleef ze Ranomi Kromowidjojo voor. De regerend olympisch kampioene tikte aan in 54,85. Bij de mannen werd Sebastiaan Verschuren tweede in 50,10. De Fransman Jeremy Stravius won in 49,40.
#
#
#
#
# 15 februari 2015, 19:14
#
# 	            Bron: ANP
#
#
#
#
# 3
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             3  +
#             0  +
#             0  =
#             3
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# © ANP
#
#
#
#
#
# Moniek Nijhuis pakte na een sterke race de winst op de 50 meter schoolslag. Ze zegevierde in 31,06. De Française Charlotte Bonnet finishte als tweede in 31,95. Op de 400 meter vrij werd Maarten Brzoskowski tweede in 3.55,34. Maaike de Waard werd tweede op de 50 meter rugslag in 28,64. Ze zwom zaterdag ook al naar het zilver op de dubbele afstand.Heemskerk was zaterdag de beste op de 200 vrij, in 1.56,87. Kromowidjojo en Dekker kregen beiden op de 50 meter vlinder een gouden plak, aangezien ze allebei de winnende tijd van 26,07 klokten.
#
#
#
#
#
#
#
#
#
#
#
#
# Volg en lees meer over:
#
#
#
#
#  Watersport
#
#
#
#
#
#  Watersport
#
#
#
#
#  Zwemmen
#
#
#
#
#
#  Zwemmen
#
#
#
#
#  Andere sporten
#
#
#
#
#
#  Andere sporten
#
#
#
#
#  Sport
#
#
#
#
#
#  Sport
#
#
#
#
#  Femke Heemskerk
#
#
#
#
#
#  Femke Heemskerk
#
#
#
#
#  Ranomi Kromowidjojo
#
#
#
#
#
#  Ranomi Kromowidjojo
#
#
#
#
#
#
#
#
#
# 		DART.showGoogleAd( "ligatus--medium--1" );
#
#
#
#
# 		DART.showGoogleAd( "ligatus--large--1" );
#
#
#
#
#
#
#
#
# Sidebar
#
#
#
#
#
#
#
#
#
#
#
#                     Gerelateerde artikelen
#
#
#
#
#
#
#
#
#
#
# Grange pakt slalomgoud na uitglijder favoriet Hirscher
#
#
#
# 15 feb 2015
#
#
#
#
#
#
#
#
#
# Inzet Veltman onzeker voor duel met Legia
#
#
#
# 15 feb 2015
#
#
#
#
#
#
#
#
#
# Arsenal dankzij 2 goals Giroud verder in FA Cup
#
#
#
# 15 feb 2015
#
#
#
#
#
#
#
#
#
#
#
# 	if ( DART.returnDevice() === "large" ){
#     	DART.showGoogleAd( "mid--large--1" );
#     }
#
#
#
#
#
# Meest gelezen Sport
#
#
#
#
#
# 1
#  14575
#
#
#
#
#
# De Russische spookstad van 40 miljard
#
#
#
#
# Sport
#
#
#
#
#
#
#
#
# 2
#  13319
#
#
#
#
#
# Apps zijn net zo slordig als stappentellers
#
#
#
# Tech
#
#
#
#
#
#
#
#
# 3
#  10786
#
#
#
#
#
# Spakenburg frustreert dopingonderzoek op 'verwijtbare' manier
#
#
#
# Sport
#
#
#
#
#
#
#
#
# 4
#  9239
#
#
#
#
#
# Max Verstappen is geboren om te racen
#
#
#
#
# Sport
#
#
#
#
#
#
#
#
# 5
#  9173
#
#
#
#
#
# Ontketende Kramer pakt goud op vijf kilometer
#
#
#
# Sport
#
#
#
#
#
#
#
#
#
#  Bekijk hele lijst
#
#
#
#
#
# 		if ( DART.returnDevice() === "large" ){
# 			DART.showGoogleAd( "rectangle--large--1" );
# 		}
#
#
#
#
#
#
#
#
#
#
#
# 	if ( DART.returnDevice() === "small" ){
#     	DART.showGoogleAd( "mid--small--1" );
#     }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Verder in Nieuws
#
#
#
#
#
# Buitenland
#
#
#
#
#
#
#
#
#
# Tot twee keer toe weet dader te ontsnappen in Kopenhagen
#
#
#
#
# 24
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             24  +
#             0  +
#             0  =
#             24
#
#
#
#
#
#
#                             Buitenland
#
#
#
#
#
#
#
# Binnenland
#
#
#
#
#
#
#
#
#
# Kramer onttroont Bergsma met wereldrecord op laaglandbaan
#
#
#
#
# 8
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             8  +
#             0  +
#             0  =
#             8
#
#
#
#
#
#
#                             Binnenland
#
#
#
#
#
#
#
#
# Opinie
#
#
# Stekel
#
#
# Sandervan Walsum
#
#
#
#
#
# 4
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             3  +
#             1  +
#             0  =
#             4
#
#
#
#
#  COLUMN
#
#
#
#
#
#
# Economie
#
#
#
#
#
#
#
#
#
# De man die de wereld aan de Nutella bracht
#
#
#
#
# 7
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             7  +
#             0  +
#             0  =
#             7
#
#
#
#
#
#
#                             Economie
#
#
#
#
#
#
#
#
# Sport
#
#
#
#
#
#
#
#
#
# Max Verstappen is geboren om te racen
#
#
#
#
# 17
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             17  +
#             0  +
#             0  =
#             17
#
#
#
#
#
#
#                             Sport
#
#
#
#
#
#
#
#
# Tech
#
#
#
#
#
#
#
#
#
# De Drie Apps van de Week: Limbo, Evoland en Blendle Trending
#
#
#
#
# 6
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             6  +
#             0  +
#             0  =
#             6
#
#
#
#
#
#
#                             Tech
#
#
#
#
#
#
#
# Media
#
#
#
#
#
#
#
#
#
# Als ik wil twitteren denk ik: Oude trut, bemoei je er niet mee
#
#
#
#
# 10
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             10  +
#             0  +
#             0  =
#             10
#
#
#
#
#
#
#                             Media
#
#
#
#
#
#
#
#
# Wetenschap
#
#
#
#
#
#
#
#
#
# Pompgemak
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#                             Wetenschap
#
#
#
#
#
#
#
#
# Politiek
#
#
#
#
#
#
#
#
#
# #binnenskamers: kabinet stuurt nieuws MH17 retour
#
#
#
#
# 102
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             102  +
#             0  +
#             0  =
#             102
#
#
#
#
#
#
#                             Politiek
#
#
#
#
#
#
#
# Vonk
#
#
#
#
#
#
#
#
#
# Met bevende handen veegde ik mijn tranen weg
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
#
#                             Vonk
#
#
#
#
#
#
#
# Televisie
#
#
#
# Logeren
#
# Voor Chantal moet Expeditie Robinson een eitje zijn
#
#
#
# AafBrandt Corstius
#
#
#
#
# 1
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             1  =
#             1
#
#
#
#
#  COLUMN
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Verder in Cultuur & Leven
#
#
#
#
#
# Recensies
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Karen Dawisha beschrijft corrupt regime van Poetin verbluffend nauwkeurig
# Inktzwart beeld van Poetins...
#
#
#
#
# 13
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             12  +
#             1  +
#             0  =
#             13
#
#
#
#
#
# Recensies
#
#
#
#
#
#
# Film
#
#
#
#
#
#
#
#
#
# De film die 'Fifty shades' preuts maakt
#
#
#
#
# 5
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             5  +
#             0  +
#             0  =
#             5
#
#
#
#
#
#
#                             Film
#
#
#
#
#
#
#
#
# Muziek
#
#
#
#
#
#
#
#
#
# Paloma Faith een bitch? Nee, een heerlijke meid
#
#
#
#
# 15
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             15  +
#             0  +
#             0  =
#             15
#
#
#
#
#
#
#                             Muziek
#
#
#
#
#
#
#
# Reizen
#
#
#
#
#
#
#
#
#
# Buitenzwemmen onder alle omstandigheden
#
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#                             Reizen
#
#
#
#
#
#
#
#
# Koken & Eten
#
#
#
#
#
#
#
#
#
# 'Bier en psychiatrie, dat gaat toch niet samen?'
#
#
#
#
# 19
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             19  +
#             0  +
#             0  =
#             19
#
#
#
#
#
#
#                             Koken & Eten
#
#
#
#
#
#
#
#
# Theater
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Forbidden Zone
#
#
#
#
#                             Theater
#
#
#
# 2
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             2  +
#             0  +
#             0  =
#             2
#
#
#
#
#
#
#
#
#
#
# Boeken
#
#
#
#
#
# 	                De condition humaine is een...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Edward O. Wilson
# The meaning of human existence
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
# 	                        Non-fictie
#
#
#
#
#
#
# Beeldende Kunst
#
#
#
#
#
#
#
#
#
# Niets-aan-de-handkunst uit een foute periode
#
#
#
#
# 4
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             4  +
#             0  +
#             0  =
#             4
#
#
#
#
#
#
#                             Beeldende Kunst
#
#
#
#
#
#
#
#
# Leven
#
#
#
#
#
#
#
#
#
# Feministische pornomaakster bekritiseert 50 shades
#
#
#
#
# 19
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             19  +
#             0  +
#             0  =
#             19
#
#
#
#
#
#
#                             Leven
#
#
#
#
#
#
#
#
# Mode & Mooi
#
#
#
#
#
#
#
#
#
# In de winkel
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
#
#                             Mode & Mooi
#
#
#
#
#
#
#
#
# Festivals
#
#
#
#
#
#
#
#
#
# Gast van de Volkskrant Job de Wit: 'De programmeur van Le Guess Who? snapt het
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
#
#                             Festivals
#
#
#
#
#
#
#
# Televisie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Black Sails Seizoen 1
# Dvd-tip
#
#
#
#
# 0
#
#
#
#  Artikel bewaren
#
#
#  Artikel bewaren
#
#
#
#             0  +
#             0  +
#             0  =
#             0
#
#
#
#
#
# Televisie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Nieuws
#
#
# Sport
#
#
# Heemskerk blijft Kromowidjojo voor in Amiens
#
#
#
#
#
#
#
#
#
# Nu bij de Volkskrant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Naar de winkel
#
#
#
#
#
#
#
#
#
#
#
#
# Twitter
#
#
#
#
#
# Facebook
#
#
#
#
#
# Google+
#
#
#
#
#
#
# Volg de Volkskrant
#
#
# Schrijf u in voor de dagelijkse nieuwsbrief
#
#
#
#
#
#
# Aanvragen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Archief
#
#
#
#
#
# Digitale krant
#
#
#
#
#
# Journalisten Columnisten
#
#
#
#
#
#
# Apps
#
#
# de Volkskrant
#
#
# de Volkskrant Original
#
#
# de Volkskrant Select
#
#
# Overzicht alle apps
#
#
#
#
#
#
#
# de Volkskrant
#
# Over de Volkskrant
# Auteursrecht & Privacy
# Vacatures
# Over deze website
# RSS feeds
#
#
#
#
#
# Service en contact
#
# Abonneren
# Service
# Veelgestelde vragen
# Contactgegevens
# Adverteren
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                         © 2015 - Alle rechten voorbehouden
# Lees de gebruiksvoorwaarden
#
#
#
#
#
#
#
#
#
#
# Nieuws
#
#
# Cultuur & Leven
#
#
#
#
#
#
#
#
#
#
#
#
#
# Weer
#
#
#
#
#
# Beurs
#
#
#
#
#
# Voorpagina
#
#
# Buitenland
#
#
# Binnenland
#
#
# Opinie
#
#
# Economie
#
#
# Sport
#
#
# Tech
#
#
# Media
#
#
# Wetenschap
#
#
# Politiek
#
#
# Specials
#
#
# Cartoons
#
#
# Foto
#
#
# Vonk
#
#
# Dag In Dag uit
#
#
# Abonnement
#
#
# Winkel
#
#
# Service
#
#
#
#
#
#
#
#
#
#
#
#
#
# Voorpagina
#
#
# Agenda
#
#
# Recensies
#
#
# Film
#
#
# Muziek
#
#
# Reizen
#
#
# Koken & Eten
#
#
# Theater
#
#
# Boeken
#
#
# Beeldende Kunst
#
#
# Leven
#
#
# Mode & Mooi
#
#
# Festivals
#
#
# Televisie
#
#
# Voordeel
#
#
# Abonnement
#
#
# Winkel
#
#
# Service
#
#
#
#
#
#
#
# Mijn Volkskrant
#
#
#
#
#  Mijn nieuws
#  Ik volg
#  Lees later
#  Account
#  Uitloggen
#   Inloggen
#
#
# Mijn nieuws
#
#
#
#
#  Ik volg
#
#
#
#
#  Lees later
#
#
#
#                 Account
#
#
#  Uitloggen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ©
#
# Tweets by @
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="//platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#
#
#
#
#
#
# 1
#
#
#
#
#
# Previous
# Next
#
#
#
#
#
#
#
#
#
# De Volkskrant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Deel dit
#
#
#
#
#
#
#
#
#
#
#                             Twitter
#
#
#
#
#
#
#
#
#
#
#
#
#                             Facebook
#
#
#
#
#
#
#
#
#
#
#
#
#                             Linkedin
#
#
#
#
#
#
#
#
#
#
#
#
#                             Google +
#
#
#
#
#
#
#
#
#
#
#
#
#                             E-mail
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# |
#
#
#
#
#
#
#
#
#
#
#
#
# U kunt deze maand nog 5/10 gedeelde VK-plus artikelen gratis lezen.
# Probeer VK-plus 2 weken gratis,zonder verplichtingen
#
#
# Gratis proberen
#
#
#
#                                     Al een account? Log in
#
#
#
# De Volkskrant biedt gratis en betaalde artikelen aan. Betaalde artikelen herkent u aan een VKplus label. Elke maand mag u gratis 10 VKplus artikelen lezen die uw vrienden met u delen.
#
#
#
#
#
# Alles van de Volkskrant
# Complete cultuuragenda
# Stel uw Volkskrant samen
# Deel favoriete artikelen
# De mooiste fotografie
#
#  Lees meer over VKplus?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# U heeft deze maand 5/10 gedeelde VK-plus artikelen gratis gelezen.
#
#
#
#
#
#
#
#
#
#
#
# Cookies op de Volkskrant
#
# Door gebruik te maken van deze website, of door op 'Akkoord' te klikken, geeft u toestemming voor het gebruik van cookies.
# De Volkskrant maakt gebruik van cookies, onder andere om de website te analyseren, het gebruiksgemak te vergroten en advertenties te tonen. Door gebruik te maken van deze website, of door op 'Akkoord' te klikken, geeft u toestemming voor het gebruik van cookies. Wilt u meer informatie over cookies en hoe ze worden gebruikt, bekijk dan ons cookiebeleid.
#
#
#
#
#
#  Akkoord
#
# Meer informatie
#
#
#
#
#
#
#
#
#
#
#         var _sf_async_config={};
#         /** CONFIGURATION START **/
#         _sf_async_config.uid = 46966;
# 	       _sf_async_config.domain = 'volkskrant.nl';
#         _sf_async_config.useCanonical = true;
#         _sf_async_config.sections = 'sport'; //CHANGE THIS
#         _sf_async_config.authors = 'UNKNOWN';
#         /** CONFIGURATION END **/
#         (function(){
#             function loadChartbeat() {
#                 window._sf_endpt=(new Date()).getTime();
#                 var e = document.createElement('script');
#                 e.setAttribute('language', 'javascript');
#                 e.setAttribute('type', 'text/javascript');
#                 e.setAttribute('src', '//static.chartbeat.com/js/chartbeat.js');
#                 document.body.appendChild(e);
#                 }
#                 var oldonload = window.onload;
#                 window.onload = (typeof window.onload != 'function') ?
#                 loadChartbeat : function()
#                 { oldonload(); loadChartbeat(); }
#                 ;
#         })();
#
#
#
#
#
#
# 	if ( DART.returnDevice() === "large" ){
#     	DART.showGoogleAd( "layer--large--1" );
#     }
#
#
#
#
# 	if ( DART.returnDevice() === "medium" ){
#     	DART.showGoogleAd( "layer--medium--1" );
#     }

# %%
# 1.7

# %%
# import urllib2
# from bs4 import BeautifulSoup
# from bs4 import UnicodeDammit
# from lxml import etree
# from lxml import objectify
# import csv

# # 1.1
# url="http://static3.volkskrant.nl/static/nmc/nmc/frameset/footer/rss/rssFeeds.html?language=nl&pageType=integration&navigation=Voorpagina&language=nl&navigationItemId=20002"
# f=urllib2.urlopen(url)

# soup = BeautifulSoup(f)
# links = []
# for link in soup.findAll("a"):    
#     linktext = link.get("href")
#     if linktext != None:
#         if linktext[-3:] == "xml":
#             links.append(UnicodeDammit(linktext).unicode_markup)


# # 1.2            
# fileNames = []            
# for linkUrl in links:
#     rssPage = urllib2.urlopen(linkUrl)
    
#     # write the files to the Data folder as xml and use the feedname as filename
#     fileName = "Data/"
#     fileName += linkUrl[25:-4].replace("/", "_")
#     fileName += ".xml"

#     fileNames.append(fileName)
    
#     rssFile = open(fileName, 'w+')
    
#     rssFile.writelines(rssPage.readlines())
#     rssFile.close()

    
    
# # 1.3    
# xmlDictList = []
# for rssFileName in fileNames:
    
#     # open all the files
#     rssFile = open(rssFileName, "r")

#     # parse the xml
#     parsedRss = etree.parse(rssFile)
    
#     # get the channel name from the filename
#     channel = rssFileName[5:-4]
    
#     #get all rss items
#     items = parsedRss.xpath('//item')
    
#     # make a dict for each rss item, and append to list
#     for item in items:
#         xmlDict = {}
#         xmlDict["title"] = item.find("title").text
#         xmlDict["channel"] = channel
#         xmlDict["url"] = item.find("link").text
#         xmlDict["date"] = item.find("pubDate").text
#         xmlDictList.append(xmlDict)

# # 1.4
# numberPerChannel = {}

# for xmlDict in xmlDictList:
    
#     if xmlDict["channel"] in numberPerChannel:
    
#         numberPerChannel[xmlDict["channel"]] += 1
        
#     else:
        
#         numberPerChannel[xmlDict["channel"]] = 1

# nonDoubles = []
# doubles = 0
# for item in items:
#     if xmlDict["title"] not in nonDoubles:
#         nonDoubles.append(xmlDict["title"])
        
#     else:
#         doubles += 1
        
    
# print "Total number of rss items:", len(xmlDictList)
# print numberPerChannel
# print "Number of doubles:", doubles

# #1.5
# with open('Data/xmlDictList.csv', 'w+') as csvFile:
    

#     writer = UnicodeWriter(csvFile, delimiter =",",  quoting=csv.QUOTE_ALL)
#     writer.writerow(['title', 'channel', 'url', 'date'])
#     for xmlDict in xmlDictList:

#         writer.writerow([xmlDict['title'], xmlDict['channel'], xmlDict['url'], xmlDict['date']])
    
#     csvFile.close()

# %% [markdown]
# ## JSON parsing
#
#     1. Download http://maartenmarx.nl/teaching/ISatWork/NoteBooks/consuming-json-data-from-a-web-service.ipynb, remove all code blocks, and turn it into a notebook again.
#
#     2. Check that what you did is correct and you did not remove too much using a notebook viewer.
#
#     3. Now extract all code from the downloaded notebook, save it to a file, and execute it as a Python script. Does it give errors? Is it syntactically correct?

# %%
import urllib2
from bs4 import BeautifulSoup
import simplejson as json

# 2.1 & prep for 2.3
url = "http://maartenmarx.nl/teaching/ISatWork/NoteBooks/consuming-json-data-from-a-web-service.ipynb"
jsonFile = urllib2.urlopen(url).read()
jsonObj = json.loads(jsonFile)

# create two lists: for code and non-code cells
nonCodeCells = [c for c in jsonObj["worksheets"][0]["cells"] if c["cell_type"] != "code"]
codeCells = [c for c in jsonObj["worksheets"][0]["cells"] if c["cell_type"] == "code"]

# set the cells in the json object to only non code cells
jsonObj["worksheets"][0]["cells"] = nonCodeCells


with open("JSON.ipynb", "w+") as jsonIPynb:
    json.dump(jsonObj, jsonIPynb)

# %% [markdown]
# ## 2.2
#
# the code runs fine, to test for yourself open the notebook.

# %%
# 2.3
with open("Data/JSONparsing.py", "w+") as pythonFile:
    for codeCell in codeCells:
        pythonFile.writelines(codeCell["input"])
        pythonFile.write('\n')
    pythonFile.close()

# %% [markdown]
# Most of the code runs fine
#
# However at the last line we get the following:
#
# >strict_decoder
# >
# >^
# >
# >IndentationError: expected an indented block
#
# Ergo the code is not correct.

# %% [markdown]
# ##PDF parsing
#
#     1. Save a wordfile as PDF, open it in Python, extract all text. Describe the differences, if any. Try the same with a two column PDF file from the web. This exercise gets more interesting if you use difficult PDF. Why not try http://www.stdout.org/~winston/latex/latexsheet.pdf?
#
#     2. Is the word order still as it should be?
#
#     3. What about the strange characters?

# %% [markdown]
# ## 1.
#
# Since the following python solutions for pdf text extractions continued to result in errors:
#
# - [slate](https://pypi.python.org/pypi/slate)
# - [pdfminer](https://pypi.python.org/pypi/pdfminer/)
# - [pypdf](https://pypi.python.org/pypi/pyPdf/1.13) (discontinued and followup is a dead link)
#
# We have used the following [website](http://www.onlineocr.net/) to extract the text from the pdf files contained within our Data folder.
#
# Here the different markups were lost during the ocr as well as any linebreaks, leaving the text of the sample pdf in a single line.
#
# ## 2.
#
# For latexsheet.pdf the word order was no longer as it should be. The word order was line by line with no regard for the colums.
#
# ## 3.
#
# The special characters were interpreted as legal characters in utf-8, meaning they did not match the actual characters

# %%
# how it should work

# import pdfminer
# import slate
# import io

# pdfFileName = "Data/PDF-Word.pdf"

# latexSheetFileName = "Data/latexsheet.pdf"

# pdfFile = io.FileIO(latexSheetFileName, "rb")

# print slate.PDF(pdfFile)

# %%
# attempt 2

# from pdfminer.pdfparser import PDFParser
# from pdfminer.pdfdocument import PDFDocument
# from pdfminer.pdfpage import PDFPage
# from pdfminer.pdfpage import PDFTextExtractionNotAllowed
# from pdfminer.pdfinterp import PDFResourceManager
# from pdfminer.pdfinterp import PDFPageInterpreter
# from pdfminer.pdfdevice import PDFDevice
# import io

# # Open a PDF file.
# fp = io.FileIO('Data/simple1.pdf', 'rb')
# # Create a PDF parser object associated with the file object.
# parser = PDFParser(fp)
# # Create a PDF document object that stores the document structure.
# # Supply the password for initialization.
# document = PDFDocument(parser)
# # Check if the document allows text extraction. If not, abort.
# if not document.is_extractable:
#     raise PDFTextExtractionNotAllowed
# # Create a PDF resource manager object that stores shared resources.
# rsrcmgr = PDFResourceManager()
# # Create a PDF device object.
# device = PDFDevice(rsrcmgr)
# # Create a PDF interpreter object.
# interpreter = PDFPageInterpreter(rsrcmgr, device)
# # Process each page contained in the document.


# for page in PDFPage.create_pages(document):
    
    
#     interpreter.process_page(page)
    
# print document.info
# # print interpreter.get_current_state()
