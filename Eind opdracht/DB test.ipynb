# %%
# imports and general setup
# %matplotlib inline 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import requests
import StringIO
import zipfile
import scipy.stats 
import json
import argparse
import os
import sqlite3
import csv
import codecs

import urlparse
import urllib2

# sets the graphs to a larger size
plt.rcParams['figure.figsize'] = (19, 7)

# %% [markdown]
# # versie 1
#
# Aantal veldslagen aanvallend, tegenover het aantal veldslagen dat deze partij de verdedigende partij was. Misschien kunnen we dit ook nog bekijken per oorlog of theater?
#
# Is het mogelijk om een overzicht te krijgen van de oorlogszuchtige daden van alle Duitse staatjes die later Duitsland vormden? Zullen we deze er dan vervolgens bij Duitsland optellen in een apart overzicht? Hetzelfde geldt voor de Verenigde Staten en mogelijk de Italiaanse stadstaten?
#
# Verder is het misschien mogelijk om te kijken hoeveel staten zijn meegesleept in een oorlog als derde partij? Een land dat dus pas bij het tweede of een later gevecht meedoet aan het conflict? Misschien dit presenteren met de betreffende gevechten erbij, dan kan ik er mooi wat research naar doen?
#
# Natuurlijk allen voorzien van mooie plaatjes als dat kan.

# %% [markdown]
# # versie 2
#
# Per oorlog de initiator en de aggressor vinden. Voor aggressor geld het meeste aanvallende veldslagen binnen de oorlog.

# %%
def getZIP(): # Get zipfile function
    request = requests.get('https://github.com/jrnold/CDB13/archive/master.zip').content # Requests content of zipfiles
    string = StringIO.StringIO(request)
    zf = zipfile.ZipFile(string, 'r') # Gets a list of zipfiles
    return zf

# %%
# download the CDB13 zip from github
zippedDB = getZIP()
dbFiles = zippedDB.namelist()

# for i in dbFiles:
#     if i[12:18] == ('/data/') and i[-4:] == '.csv':
#         print i

# %%
battles = pd.read_csv(zippedDB.open(dbFiles[dbFiles.index('CDB13-master/data/battles.csv')]))
battleActors = pd.read_csv(zippedDB.open(dbFiles[dbFiles.index('CDB13-master/data/battle_actors.csv')]))
battles.head()
# Out:
#    isqno                               war            name              locn  \
# 0      1  NETHERLAND'S WAR OF INDEPENDENCE        NIEUPORT  SPANISH FLANDERS
# 1      2                 THIRTY YEAR'S WAR  WHITE MOUNTAIN           BOHEMIA
# 2      3                 THIRTY YEAR'S WAR         WIMPFEN        PALATINATE
# 3      4                 THIRTY YEAR'S WAR   DESSAU BRIDGE            ANHALT
# 4      5                 THIRTY YEAR'S WAR          LUTTER         BRUNSWICK
#
#                                campgn  postype post1 post2  front  depth  \
# 0                       NIEUPORT 1600        0    HD   NaN      0      0
# 1                        BOHEMIA 1620        1    HD    PD      1      0
# 2                     PALATINATE 1622        0    HD   NaN      0      0
# 3  DANISH INVASION OF GERMANY 1625-26        0    PD   NaN      0      0
# 4  DANISH INVASION OF GERMANY 1625-26        0    HD   NaN      0      0
#
#    ...    is_hero                              war2  \
# 0  ...          1  NETHERLAND'S WAR OF INDEPENDENCE
# 1  ...          1                 THIRTY YEAR'S WAR
# 2  ...          1                 THIRTY YEAR'S WAR
# 3  ...          1                 THIRTY YEAR'S WAR
# 4  ...          1                 THIRTY YEAR'S WAR
#
#                                war3                       cdb13_war  \
# 0  NETHERLAND'S WAR OF INDEPENDENCE   Eighty Years War of 1568-1648
# 1                 THIRTY YEAR'S WAR  Thirty Years' War of 1618-1648
# 2                 THIRTY YEAR'S WAR  Thirty Years' War of 1618-1648
# 3                 THIRTY YEAR'S WAR  Thirty Years' War of 1618-1648
# 4                 THIRTY YEAR'S WAR  Thirty Years' War of 1618-1648
#
#    cdb13_theater                                            dbpedia  \
# 0            NaN   http://dbpedia.org/resource/Battle_of_Nieuwpoort
# 1            NaN  http://dbpedia.org/resource/Battle_of_White_Mo...
# 2            NaN      http://dbpedia.org/resource/Battle_of_Wimpfen
# 3            NaN  http://dbpedia.org/resource/Battle_of_Dessau_B...
# 4            NaN       http://dbpedia.org/resource/Battle_of_Lutter
#
#    cow_warno  cow_warname  war_initiator  parent
# 0        NaN          NaN              0     NaN
# 1        NaN          NaN              0     NaN
# 2        NaN          NaN              0     NaN
# 3        NaN          NaN              1     NaN
# 4        NaN          NaN              0     NaN
#
# [5 rows x 49 columns]

# %% [markdown]
# # Deze Thomas:

# %%
wars = battles['war']
warSet = set([x.strip() for x in wars.values])

warStartersDict = {}


for war in warSet:
    
    warBattles = battles.query('war == "' + war + '"')
    startBattle = warBattles.query('war_initiator == True')['isqno']
    warStartActors = battleActors.loc[battleActors['isqno'].isin(startBattle)]
    warStarters = warStartActors.query('attacker == 1')['actor']
    warStartersDict[war] = set(warStarters.values)
    
warStartDF = pd.DataFrame.from_dict(warStartersDict, orient='index')
warStartDF.columns = ['Starting actor 1', 'Starting actor 2', 'Starting actor 3', 'Starting actor 4']
warStartDF.index.name = 'War'
warStartDF
# Out:
#                                                Starting actor 1  \
# War
# WORLD WAR I                                             Austria
# THE NAPOLEONIC WARS                                     Austria
# WAR OF THE SPANISH SUCCESSION                           England
# MONMOUTH'S REBELLION                             English Rebels
# FRANCO-SPANISH WAR                                       France
# THE MANCHURIAN INCIDENT (1938-1939)                       Japan
# KING WILLIAM'S WAR                                       France
# AMERICAN REVOLUTION                               Great Britain
# THE FRONDE                                                 None
# ITALO-ETHIOPIAN WAR                                        None
# AUSTRO-TURKISH WAR                               Ottoman Empire
# ARAB-ISRAELI, 1948                                        Syria
# KOREAN WAR                                          North Korea
# WORLD WAR I (SERBIAN FRONT 1914)                        Austria
# GREAT NORTHERN WAR                                         None
# WAR OF THE AUSTRIAN SUCCESSION                          Prussia
# SPANISH-AMERICAN WAR                                        USA
# RUSSO-FINISH WAR (1939-1940)                               None
# WORLD WAR II (EASTERN FRONT)                            Germany
# SECOND ENGLISH CIVIL WAR                                   None
# WORLD WAR II                                              Japan
# CRIMEAN WAR                                       Great Britain
# POLISH-TURKISH WAR                                         None
# RUSSO-POLISH WAR (1920)                                  Poland
# AUSTRO-PRUSSIAN (SEVEN WEEK'S) WAR                         None
# THE SEVEN YEAR'S WAR                                    Hanover
# BOER WAR                                                   None
# WORLD WAR II (PACIFIC, 1943-1945)                   None
# ARAB-ISRAELI WAR, 1968                              None
# ...                                                  ...
# DUTCH WAR                                           None
# VIET NAM                                            None
# WORLD WAR I (TURKISH FRONTS 1915)                   None
# NETHERLAND'S WAR OF INDEPENDENCE                    None
# RUSSO-JAPANESE WAR                                  None
# ARAB-ISRAELI WAR, 1967 (SIX-DAY WAR)                None
# ZULU WAR                                            None
# WAR OF AUSTRIA WITH FRANCE AND PIEDMONT             None
# WORLD WAR II (ITALY 1944)                           None
# WORLD WAR I (EASTERN FRONT 1914)                    None
# WAR OF THE SECOND COALITION                         None
# TRANSVAAL REVOLT                                    None
# WORLD WAR I (ITALIAN FRONT 1915)                    None
# THIRTY YEAR'S WAR                                   None
# ARAB-ISRAELI, 1956                                  None
# WORLD WAR I (WESTERN FRONT 1918)                    None
# ARAB-ISRAELI WAR, 1973 (OCTOBER WAR)              Jordan
# WAR OF THE FIRST COALITION                          None
# WORLD WAR II (EUROPEAN THEATER)                     None
# WAR OF 1812                                         None
# ENGLISH CIVIL WAR                                   None
# WORLD WAR II (OKINAWA)                              None
# WORLD WAR I (WESTERN FRONT 1914)                    None
# WORLD WAR I (TURKISH FRONTS 1917)                   None
# EGYPT AND THE SUDAN                                 None
# WAR OF TEXAN INDEPENDENCE                           None
# JACOBITE REBELLION                                  None
# THE SPANISH CIVIL WAR                               None
# THE BALKAN WARS                                     None
# LATIN AMERICAN WARS OF INDEPENDENCE                 None
#
# [66 rows x 4 columns]

# %%
battleActors.head()
# Out:
#    isqno  attacker  n           actor
# 0      1         0  1  Dutch Republic
# 1     10         0  1           Spain
# 2    100         0  1         Austria
# 3    100         1  1          France
# 4     10         1  1          Sweden

# %%
warStarts = battles.query('war_initiator == True')['isqno']

warStartActors = battleActors.loc[battleActors['isqno'].isin(warStarts)]

warStartCount ={}

for i in warStartActors['actor']:
    if i not in warStartCount.keys():
        warStartCount[i] = 1
    else:
        warStartCount[i] += 1


warStartDF = pd.DataFrame.from_dict(warStartCount, orient='index')
warStartDF.columns = ['Number of wars started']
warStartDF.index.name = 'Country'
warStartDF = warStartDF.sort(columns=['Number of wars started'], ascending=False)

warStartDF[:10].plot(kind='bar')

# %%
warStartDF
# Out:
#                         Number of wars started
# Country
# USA                                         74
# Germany                                     74
# France                                      65
# Israel                                      43
# Great Britain                               40
# Austria                                     22
# Confederacy                                 22
# Russia                                      21
# Egypt                                       19
# Syria                                       16
# Prussia                                     14
# Holy Roman Empire                           13
# USSR                                        11
# Japan                                       10
# Mexico                                       8
# England                                      7
# Jordan                                       7
# Ottoman Empire                               7
# Sweden                                       6
# Spain                                        6
# Royalist                                     5
# Serbia                                       4
# Hanover                                      4
# Italy                                        4
# Dutch Republic                               3
# Parliamentarian                              3
# North Korea                                  3
# Poland                                       2
# Habsburg Empire                              2
# Independentalists                            2
# Bulgaria                                     2
# Protestant Union                             1
# Jacobites                                    1
# Bavaria                                      1
# South Vietnam                                1
# South African Republic                       1
# Spanish Republic                             1
# Iraq                                         1
# Saxony                                       1
# Texas                                        1
# Savoy                                        1
# Palestine                                    1
# North Vietnam                                1
# English Rebels                               1

# %%
# From https://github.com/okfn/dptools/blob/master/bin/load-sqlite.py
# No license given in original. Since OKFN assumed to be have open source license.
#
# Edits by Jeffrey Arnold (2014), BSD-3
#
# - converted to Python 3
#
# Further edits by Joey van Riemsdijk (2015)
#
# Now for iPython 2.2 & python 2.7



# http://www.sqlite.org/datatype3.html
mappings = {
    'string': 'text',
    'number': 'real',
    'float': 'real',
    'integer': 'integer',
    'date': 'string',
    'boolean': 'integer',
    'date': 'date',
    'datetime': 'datetime'
}


def load(dpurlOrPath, sqlitePath):
    if not dpurlOrPath.split('://')[0] in ['http', 'https', 'ftp']:
        # it's a path
        dpurl = path2url(dpurlOrPath)
    else:
        dpurl = dpurlOrPath
        # urljoin makes this work right -
        # http://docs.python.org/2/library/urlparse.html#urlparse.urljoin
        dpurl = urlparse.urljoin(dpurl, 'datapackage.json')
        basepath = dpurlOrPath.rstrip('datapackage.json')
        dpfo = urllib2.urlopen(dpurl)
        reader = codecs.getreader("utf-8")
        out = json.load(reader(dpfo))
        for finfo in out['resources']:
            # normalization so we do not have to handle both alternatives
            if not 'url' in finfo:
                finfo['url'] = urlparse.urljoin(dpurl, finfo['path'])
            process_resource(finfo, sqlitePath)


def process_resource(finfo, dbpath):
    '''Load the resource specified by finfo into the database at dbpath
    '''
    if 'name' in finfo:
        tablename = finfo['name']
    else:
        _fname = urlparse.urlparse(finfo.get('url', ''))[2].split('/')[-1]
        tablename = os.path.splitext(_fname)[0]
        
    fields = finfo['schema']['fields']
    _columns = ','.join(
        ['"%s" %s' % (field['id'], mappings[field['type']])
         for field in fields]
    )
    conn = sqlite3.connect(dbpath)
    c = conn.cursor()
    sql = 'CREATE TABLE "%s" (%s)' % (tablename, _columns)
    c.execute(sql)
    _insert_tmpl = 'insert into "%s" values (%s)' % (tablename,
                                                     ','.join(['?'] * len(fields)))
    # could do this on but not very robust and will not work on remote urls ...
    # sqlite> .mode csv
    # sqlite> .import <filename> <table>
    req = urllib2.urlopen(finfo['url'])
    reader = csv.reader(req.read().decode('utf-8').splitlines())
    # skip headers
    for row in reader:
        c.execute(_insert_tmpl, row)
    conn.commit()
    c.close()


def path2url(path):
    return urlparse.urljoin('file:', requests.get(urllib.pathname2url(os.path.abspath(path))))

# if __name__ == '__main__':
#     parser = argparse.ArgumentParser(description='Load a data package into sqlite.')
#     parser.add_argument('datapackage', help='path to datapackage')
#     parser.add_argument('sqlite', help='path to sqlite db')
#     args = parser.parse_args()
#     load(args.datapackage, args.sqlite)

# %%
# Other functions

# %%
# load(dbFiles[dbFiles.index('CDB13-master/src-data/')], 'battles.db')
